# %% [markdown]
# # Coffe Can Momentum Strategy
# This is an exploration of two coffee can strategies. The coffee can idea is where you only buy and hold for the duration of the investment period. No selling, shorting or rebalancing.
# In this notebook, I apply this technique to two strategies:
# - Buy the top performers of the last 6 months.
# - Buy the worst performers of the last 6 months.

# %% [markdown]
# ## Helper functions

# %%
from datetime import datetime
import pandas as pd

def filter_date(df):
    start_date = df.index[0]
    if start_date.month > 1:
        start_date = start_date.replace(month=6)

    if start_date.month > 6:
        start_date = start_date.replace(year=start_date.year+1)
        start_date = start_date.replace(month=1)
    df = df.iloc[df.index >= pd.to_datetime(start_date.strftime("%m-%d-%Y"))]
    df = df.iloc[(df.index.month == 6) | (df.index.month == 1)]
    return df

def get_change(df, step=1):
    df = filter_date(df)
    return (df.iloc[::step, :].pct_change(periods=1)*100).dropna()

# %% [markdown]
# ## Prepare data over period

# %%
path = "./price_change"
benchmark_ticker = 'spy'

# %%
from yahooquery import Ticker
import pandas as pd
import json

init_tickers = []
with open('./us_tickers.json', 'r') as f:
    init_tickers = json.load(f)

change_df = pd.DataFrame({})
price_df = pd.DataFrame({})

# Get benchmark (SPY)
ticker = Ticker(benchmark_ticker, asynchronous=True)
df = ticker.history(period='20y', interval='1mo', adj_ohlc=True, adj_timezone=False)
df = df.reset_index()
df['date'] = pd.to_datetime(df['date'], utc=True)
df['date'] = df['date'].dt.tz_localize(None)
close = df[['date','close']].set_index('date')
price_df = pd.concat([price_df, filter_date(close).rename(columns={"close": benchmark_ticker})], axis=1)

for idx, t in enumerate(init_tickers):
    try:
        ticker = Ticker(t, asynchronous=True)
        details = ticker.summary_detail[t]
        if 'marketCap' not in details or details['marketCap'] < 500000000:
            continue

        df = ticker.history(period='20y', interval='1mo', adj_ohlc=True, adj_timezone=False)
        df = df.reset_index()
        df['date'] = pd.to_datetime(df['date'], utc=True)
        df['date'] = df['date'].dt.tz_localize(None)
        close = df[['date','close']].set_index('date')

        price_df = pd.concat([price_df, filter_date(close).rename(columns={"close": t})], axis=1)
        change_df = pd.concat([change_df, get_change(close).rename(columns={"close": t})], axis=1)
        if idx % 100 == 0:
            change_df.to_csv("{}/change_tmp.csv".format(path), sep=';')
            price_df.to_csv("{}/price_tmp.csv".format(path), sep=';')
    except:
        pass

change_df.to_csv("{}/change.csv".format(path), sep=';')
price_df.to_csv("{}/price.csv".format(path), sep=';')
price_df.head()

# %% [markdown]
# ## Load data

# %%
price_df = pd.read_csv("{}/price.csv".format(path), sep=';')
change_df = pd.read_csv("{}/change.csv".format(path), sep=';')
price_df.head()
# Out:
#          date        spy          A         AA  AAC  AAL      AAON        AAP  \
# 0  2003-06-01  66.531387  11.928134  47.999783  NaN  NaN  3.047452  17.986330
# 1  2004-01-01  78.278030  22.489561  65.004814  NaN  NaN  3.133018  22.989416
# 2  2004-06-01  79.279274  17.864737  63.400837  NaN  NaN  3.322249  26.096426
# 3  2005-01-01  83.067123  13.490077  57.183121  NaN  NaN  2.382674  25.458477
# 4  2005-06-01  84.113289  14.045305  51.153660  NaN  NaN  2.922395  38.128647
#
#        AAPL  AAT  ...  ZIP  ZLAB  ZM  ZNTL  ZS  ZTO  ZTS  ZUO  ZWS  ZYME
# 0  0.289284  NaN  ...  NaN   NaN NaN   NaN NaN  NaN  NaN  NaN  NaN   NaN
# 1  0.342405  NaN  ...  NaN   NaN NaN   NaN NaN  NaN  NaN  NaN  NaN   NaN
# 2  0.493877  NaN  ...  NaN   NaN NaN   NaN NaN  NaN  NaN  NaN  NaN   NaN
# 3  1.167153  NaN  ...  NaN   NaN NaN   NaN NaN  NaN  NaN  NaN  NaN   NaN
# 4  1.117371  NaN  ...  NaN   NaN NaN   NaN NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 3108 columns]

# %% [markdown]
# ## Filter data

# %%
start_year = datetime(year=2004,month=1,day=1)
end_year = datetime(year=2023,month=1,day=1)

price_df = price_df[pd.to_datetime(price_df["date"]) >= start_year].dropna(axis=1, how='all')
price_df = price_df[pd.to_datetime(price_df["date"]) <= end_year].dropna(axis=1, how='all')

change_df = change_df[pd.to_datetime(change_df["date"]) >= start_year].dropna(axis=1, how='all')
change_df = change_df[pd.to_datetime(change_df["date"]) <= end_year].dropna(axis=1, how='all')

# %% [markdown]
# ## Simple Momentum Coffee Can Algorithm
# for each ticker:
#
#     - compute change over period
#     - store computed changes and prices
#
# for each date:
#
#     - get top N best movers over period
#     - invest M money into the top N movers

# %%
import numpy as np
import math

# Algo params
periodic_alloc_amount = 6000
top_N = 20
portfolio = {}
benchmark = {}

# Create dict for tickers and their column index
col_idx = {}
for idx, c in enumerate(change_df.columns.to_numpy()[1:]):
    col_idx[idx] = c

# Algo
total_invested = 0
for _, data in enumerate(change_df.to_numpy()):
    date = data[0]
    arr = data[1:].astype(float)

    # Get top movers
    np.nan_to_num(arr, copy=False, nan=-np.inf)
    sorted_idx = np.argsort(arr)
    sorted_arr = arr[sorted_idx]
    top_movers = sorted_arr[-top_N : ]
    top_movers_idx = sorted_idx[-top_N : ]

    am = periodic_alloc_amount/top_N
    total_invested += periodic_alloc_amount
    # Get price data for top movers and buy them
    for t in top_movers_idx:
        price = price_df[price_df['date'] == date][col_idx[t]].values[0]
        shares = math.floor(am/price)
        #if date == '2004-01-01':
        #    print('invested {} in {}'.format(price*shares, col_idx[t]))
        if col_idx[t] not in portfolio:
            portfolio[col_idx[t]] = shares
        else:
            portfolio[col_idx[t]] = portfolio[col_idx[t]] + shares
    
    # Benchmark
    price = price_df[price_df['date'] == date][benchmark_ticker].values[0]
    shares = math.floor(periodic_alloc_amount/price)
    if benchmark_ticker not in benchmark:
        benchmark[benchmark_ticker] = shares
    else:
        benchmark[benchmark_ticker] = benchmark[benchmark_ticker] + shares
    

print(portfolio)
print(benchmark)
print(total_invested)

# portfolio valuation
valuation = 0
for stock, shares in portfolio.items():
    price = price_df.iloc[-1:][stock].values[0]
    valuation += price*shares

# benchmark valuation
benchmark_val = 0
price = price_df.iloc[-1:][benchmark_ticker].values[0]
benchmark_val += price*benchmark[benchmark_ticker]

print('valuation: {0:.0f}'.format(valuation))
print("performance: {0:.0f}%".format(((valuation/total_invested)-1)*100))
print('benchmark valuation: {0:.0f}'.format(benchmark_val))
print('benchmark performance: {0:.0f}%'.format(((benchmark_val/total_invested)-1)*100))
print('CAGR: {0:.0f}%'.format(((valuation/total_invested)**(1/20)-1)*100))
print('benchmark CAGR: {0:.0f}%'.format(((benchmark_val/total_invested)**(1/20)-1)*100))
# Out:
# {'HCKT': 55, 'DECK': 50, 'PRFT': 81, 'UHAL': 509, 'LNG': 88, 'CENX': 30, 'BAK': 36, 'TTMI': 17, 'CDE': 33, 'BB': 20, 'CMCO': 43, 'EQIX': 11, 'MGIC': 118, 'BBSI': 38, 'CAMT': 194, 'CALM': 82, 'ARWR': 120, 'SBRA': 18, 'EHC': 18, 'AXON': 75, 'SKX': 145, 'CME': 18, 'ADSK': 14, 'ABEV': 433, 'WCC': 16, 'GPK': 40, 'FNB': 34, 'ATI': 26, 'MT': 11, 'NSSC': 217, 'AMED': 12, 'OSTK': 42, 'HLIO': 128, 'NAT': 41, 'GOGL': 6, 'TWI': 37, 'MNST': 1550, 'DENN': 140, 'IIIN': 216, 'SEB': 0, 'MCRI': 19, 'SIRI': 785, 'BRFS': 102, 'ADEA': 77, 'CIB': 41, 'TKC': 50, 'FRO': 5, 'SIM': 44, 'CLF': 80, 'AAPL': 257, 'SPTN': 81, 'VALE': 80, 'OSPN': 75, 'VCEL': 2, 'WT': 210, 'NSP': 37, 'VRTX': 17, 'CNQ': 26, 'BLFS': 458, 'SQM': 64, 'GME': 375, 'SCVL': 48, 'TELL': 57, 'ATRO': 242, 'PFBC': 2, 'SWN': 25, 'ITRI': 6, 'ESTE': 37, 'SWBI': 222, 'NDAQ': 78, 'PAR': 30, 'FC': 39, 'GGB': 87, 'WIRE': 11, 'STRL': 16, 'AGI': 77, 'TIMB': 11, 'AMD': 7, 'ASGN': 24, 'GES': 24, 'INSM': 61, 'HOLX': 11, 'ISRG': 29, 'RES': 38, 'NVAX': 8, 'REPX': 3, 'DXPE': 31, 'SRPT': 25, 'SA': 31, 'BCRX': 91, 'TCOM': 47, 'AKAM': 8, 'AMKR': 59, 'GRMN': 9, 'ANDE': 14, 'SNEX': 18, 'AAL': 62, 'NEU': 7, 'IESC': 41, 'XPO': 247, 'THRM': 33, 'FIZZ': 117, 'UFPT': 49, 'AEHR': 305, 'MED': 22, 'NEO': 676, 'RDNT': 130, 'CF': 119, 'CCF': 23, 'IMKTA': 12, 'GT': 13, 'GIII': 27, 'ALGN': 18, 'CCOI': 22, 'ICE': 12, 'MA': 29, 'AGX': 97, 'DNN': 110, 'CPA': 7, 'IEP': 7, 'CNXN': 51, 'HALO': 67, 'GIC': 28, 'CRVL': 12, 'OPK': 383, 'SLP': 137, 'CROX': 6, 'NOV': 7, 'GTLS': 16, 'GEL': 25, 'SPNS': 261, 'AMZN': 87, 'CHE': 5, 'ANIP': 14, 'VSEC': 18, 'ACAD': 86, 'MOS': 13, 'NXST': 178, 'CORT': 275, 'FSLR': 8, 'DRD': 196, 'BIDU': 10, 'CVGW': 19, 'ICL': 144, 'AEM': 5, 'GOLD': 7, 'BVN': 35, 'PBR': 8, 'KGC': 76, 'SID': 187, 'CSIQ': 57, 'ALNY': 27, 'INCY': 57, 'BMRN': 8, 'RICK': 12, 'TGH': 25, 'TS': 5, 'PXD': 4, 'CLDX': 25, 'TITN': 9, 'CMP': 6, 'BTE': 299, 'SCHN': 3, 'WTI': 67, 'NOG': 2, 'EVO': 724, 'CRK': 24, 'JBLU': 53, 'RGLD': 7, 'OZK': 69, 'INT': 19, 'GTY': 29, 'MNRO': 21, 'MYGN': 8, 'MDRX': 35, 'ALK': 50, 'MGI': 24, 'UAL': 69, 'SMG': 13, 'TCBK': 19, 'SHEN': 46, 'ALGT': 10, 'RDN': 100, 'GERN': 103, 'BLDR': 158, 'OPCH': 39, 'SMP': 44, 'DIN': 13, 'ASH': 26, 'JAZZ': 94, 'TECK': 47, 'GSAT': 502, 'LZB': 72, 'SAH': 32, 'MODV': 27, 'MGPI': 135, 'AGEN': 82, 'UEC': 103, 'PPC': 79, 'PRMW': 54, 'CAR': 54, 'ATSG': 190, 'CTIC': 59, 'FSM': 180, 'LAC': 111, 'AJRD': 59, 'TSEM': 17, 'SSP': 54, 'ACLS': 50, 'GTN': 234, 'WNC': 158, 'TGNA': 47, 'NVMI': 66, 'GRBK': 73, 'SANM': 22, 'MERC': 124, 'DAN': 33, 'LSCC': 69, 'CASH': 35, 'GSL': 36, 'NFLX': 31, 'AGM': 29, 'CVLG': 54, 'TRS': 33, 'IMOS': 92, 'CRUS': 18, 'NBIX': 61, 'ABR': 156, 'CPE': 9, 'IDT': 74, 'NOVT': 41, 'VSH': 21, 'BKNG': 0, 'EXEL': 129, 'FOLD': 91, 'SII': 4, 'VRTS': 7, 'JKS': 60, 'GGAL': 52, 'URI': 18, 'AG': 46, 'MESO': 10, 'RTC': 17, 'UUUU': 4, 'BIIB': 2, 'APPS': 190, 'MLCO': 29, 'IOSP': 10, 'REGN': 8, 'ULTA': 4, 'PRO': 17, 'HLF': 11, 'NVGS': 9, 'DK': 25, 'HSTM': 23, 'SIMO': 52, 'WW': 35, 'HSKA': 46, 'GLNG': 11, 'IPGP': 4, 'BXMT': 37, 'GNRC': 15, 'USLM': 5, 'OXM': 6, 'TARO': 10, 'REX': 47, 'WINA': 5, 'EVRI': 198, 'ATLC': 172, 'RGR': 10, 'STAA': 27, 'LWLG': 349, 'PATK': 175, 'HROW': 169, 'SPB': 7, 'NUVA': 11, 'MDC': 14, 'AVD': 11, 'JBSS': 26, 'DDD': 13, 'HZNP': 80, 'MDXG': 210, 'TGTX': 130, 'BVH': 129, 'HOVNP': 68, 'CSWC': 60, 'PGTI': 99, 'RILY': 66, 'GMAB': 238, 'CVI': 20, 'PERI': 47, 'DQ': 199, 'VIPS': 204, 'CDMO': 123, 'AMEH': 51, 'ENPH': 234, 'RH': 8, 'ANGI': 34, 'PRTA': 33, 'SBGI': 12, 'MTG': 52, 'ARCB': 14, 'SSTK': 5, 'ADUS': 15, 'SPWR': 27, 'OSBC': 55, 'MNKD': 14, 'BLDP': 267, 'TSLA': 47, 'CLFD': 12, 'PACB': 121, 'HIMX': 23, 'COOP': 9, 'ARCT': 7, 'PLUG': 250, 'SLCA': 5, 'MARA': 120, 'SBSW': 34, 'BMA': 10, 'BBAR': 28, 'ESI': 10, 'PAM': 43, 'EDN': 39, 'BLU': 265, 'CTRE': 31, 'AVID': 55, 'INFN': 58, 'AMBA': 5, 'SWKS': 3, 'PAYC': 11, 'ALDX': 24, 'IONS': 4, 'CMPR': 3, 'PTSI': 28, 'PTCT': 5, 'AGIO': 2, 'IMGN': 62, 'DY': 5, 'W': 7, 'CZR': 38, 'RVNC': 9, 'SUPN': 17, 'NVEE': 12, 'GLOB': 9, 'NOM ...
# {'spy': 1766}
# 234000
# valuation: 1121264
# performance: 379%
# benchmark valuation: 715114
# benchmark performance: 206%
# CAGR: 8%
# benchmark CAGR: 6%

# %% [markdown]
# ## Simple Undervalued Coffee Can Algorithm (BTFD and HODL)
# for each ticker:
#
#     - compute change over period
#     - store computed changes and prices
#
# for each date:
#
#     - get top N worse movers over period
#     - invest M money into the bottom N movers

# %%
import numpy as np
import math

# Algo params
periodic_alloc_amount = 6000
bottom_N = 20
portfolio = {}
benchmark = {}

# Create dict for tickers and their column index
col_idx = {}
for idx, c in enumerate(change_df.columns.to_numpy()[1:]):
    col_idx[idx] = c

# Algo
total_invested = 0
for _, data in enumerate(change_df.to_numpy()):
    date = data[0]
    arr = data[1:].astype(float)

    # Get worse movers
    np.nan_to_num(arr, copy=False, nan=np.inf)
    sorted_idx = np.argsort(arr)
    sorted_arr = arr[sorted_idx]
    worse_movers = sorted_arr[:bottom_N]
    worse_movers_idx = sorted_idx[:bottom_N]

    am = periodic_alloc_amount/bottom_N
    total_invested += periodic_alloc_amount
    # Get price data for top movers and buy them
    for t in worse_movers_idx:
        price = price_df[price_df['date'] == date][col_idx[t]].values[0]
        shares = math.floor(am/price)
        #if date == '2008-01-01':
        #    print('invested {} in {}'.format(price*shares, col_idx[t]))
        if col_idx[t] not in portfolio:
            portfolio[col_idx[t]] = shares
        else:
            portfolio[col_idx[t]] = portfolio[col_idx[t]] + shares
    
    # Benchmark
    price = price_df[price_df['date'] == date][benchmark_ticker].values[0]
    shares = math.floor(periodic_alloc_amount/price)
    if benchmark_ticker not in benchmark:
        benchmark[benchmark_ticker] = shares
    else:
        benchmark[benchmark_ticker] = benchmark[benchmark_ticker] + shares
    

print(portfolio)
print(benchmark)
print(total_invested)

# portfolio valuation
valuation = 0
for stock, shares in portfolio.items():
    price = price_df.iloc[-1:][stock].values[0]
    valuation += price*shares

# benchmark valuation
benchmark_val = 0
price = price_df.iloc[-1:][benchmark_ticker].values[0]
benchmark_val += price*benchmark[benchmark_ticker]

print('valuation: {0:.0f}'.format(valuation))
print("performance: {0:.0f}%".format(((valuation/total_invested)-1)*100))
print('benchmark valuation: {0:.0f}'.format(benchmark_val))
print('benchmark performance: {0:.0f}%'.format(((benchmark_val/total_invested)-1)*100))
print('CAGR: {0:.0f}%'.format(((valuation/total_invested)**(1/20)-1)*100))
print('benchmark CAGR: {0:.0f}%'.format(((benchmark_val/total_invested)**(1/20)-1)*100))
# Out:
# {'BHC': 34, 'PSMT': 58, 'FCN': 20, 'WT': 5999, 'RGEN': 278, 'SRPT': 60, 'VRTX': 30, 'AORT': 110, 'PTSI': 158, 'FNB': 65, 'EXAS': 173, 'DENN': 576, 'LUMN': 69, 'STAA': 162, 'RYAAY': 20, 'BLFS': 1374, 'ABC': 28, 'NSSC': 528, 'CLH': 78, 'DMRC': 24, 'CCOI': 152, 'DSGX': 272, 'REPX': 54, 'MTZ': 55, 'HSKA': 75, 'AMKR': 106, 'QDEL': 50, 'RDNT': 586, 'CIEN': 11, 'NVMI': 75, 'RDWR': 35, 'IMOS': 528, 'SPNS': 140, 'VCEL': 130, 'MED': 105, 'RMBS': 16, 'RDY': 39, 'BBAR': 311, 'XPO': 513, 'NFLX': 182, 'TSEM': 10, 'MGPI': 651, 'NVAX': 106, 'AEIS': 42, 'ALGN': 34, 'OPK': 833, 'IESC': 64, 'DRD': 234, 'ALE': 14, 'ADTN': 23, 'ARWR': 441, 'VIAV': 30, 'NOVT': 119, 'OMCL': 40, 'SNPS': 17, 'CTIC': 374, 'BAK': 32, 'HLIT': 62, 'CALM': 149, 'TREX': 383, 'BIIB': 8, 'GPK': 95, 'OFG': 30, 'BLU': 677, 'INSM': 141, 'AXON': 29, 'SIM': 78, 'SYNA': 21, 'MGIC': 246, 'AMOT': 109, 'AGX': 182, 'TARO': 23, 'TPX': 158, 'PRMW': 80, 'JBSS': 36, 'THC': 10, 'MOH': 17, 'TTWO': 18, 'MVIS': 757, 'NEO': 1428, 'NYMT': 23, 'PBH': 24, 'FBP': 185, 'GDEN': 129, 'NXST': 84, 'TOL': 9, 'NBIX': 28, 'AGEN': 91, 'CYRX': 314, 'ANIP': 50, 'KTOS': 10, 'SVA': 130, 'EXPE': 15, 'AMD': 146, 'PERI': 262, 'PAR': 23, 'MMS': 59, 'KBH': 8, 'NVR': 0, 'CHS': 15, 'COHU': 22, 'BZH': 9, 'EVO': 1239, 'CORT': 383, 'IMAX': 76, 'PLXS': 17, 'CRMT': 28, 'AEHR': 280, 'GPRE': 17, 'OPCH': 133, 'CLS': 50, 'LWLG': 722, 'VICR': 30, 'WOLF': 19, 'DXCM': 134, 'DRS': 597, 'RTC': 11, 'AAL': 267, 'CRVL': 22, 'AVDL': 14, 'MTH': 11, 'CLDX': 162, 'BVH': 62, 'CPRX': 1522, 'MLCO': 29, 'ALK': 47, 'PHM': 15, 'CDMO': 171, 'CAL': 16, 'CAMT': 211, 'CELH': 2687, 'RDN': 259, 'MGI': 188, 'SWBI': 116, 'MTG': 69, 'JCI': 28, 'SLM': 43, 'EVRI': 408, 'RAMP': 41, 'UUUU': 67, 'INFN': 29, 'AVTA': 63, 'ATLC': 152, 'UAL': 151, 'LNG': 69, 'CROX': 37, 'PFBC': 56, 'IDT': 185, 'DVAX': 242, 'ATSG': 300, 'EWBC': 53, 'ACAD': 333, 'GSAT': 3190, 'LAD': 73, 'DAL': 59, 'BANR': 6, 'FHN': 55, 'AIG': 17, 'CENX': 112, 'PPC': 559, 'ACLS': 303, 'SIRI': 2647, 'NWG': 50, 'PATK': 1219, 'CPE': 14, 'SAFE': 61, 'TECK': 98, 'CAR': 434, 'ENLC': 188, 'MODV': 139, 'LVS': 87, 'GTN': 922, 'WNC': 475, 'MDGL': 39, 'MDXG': 714, 'DAC': 14, 'APPS': 257, 'MERC': 680, 'KRO': 155, 'STBA': 35, 'FRME': 46, 'SBCF': 63, 'NVGS': 28, 'BXMT': 100, 'MWA': 97, 'PNFP': 24, 'FOLD': 212, 'RILY': 417, 'TMUS': 32, 'BUSE': 44, 'GMAB': 468, 'HURN': 12, 'SHYF': 58, 'NUVA': 10, 'LGND': 45, 'OSBC': 496, 'FCEL': 1765, 'GRBK': 443, 'CSIQ': 108, 'BP': 20, 'EXEL': 174, 'LAC': 517, 'RIG': 8, 'AGO': 28, 'SPWR': 171, 'UCBI': 40, 'CASH': 69, 'ATEC': 10, 'HROW': 261, 'SKX': 43, 'STRA': 10, 'WY': 19, 'TGTX': 261, 'TNP': 10, 'ALNY': 29, 'BCRX': 441, 'MNKD': 284, 'PLUG': 801, 'BB': 50, 'DNN': 156, 'GDOT': 30, 'AVXL': 358, 'FRO': 75, 'QNST': 130, 'HOLI': 34, 'UEC': 98, 'JKS': 46, 'DHT': 47, 'FSLR': 26, 'DQ': 467, 'GSL': 23, 'SKY': 177, 'CALX': 39, 'PACB': 204, 'AMED': 28, 'CRK': 132, 'CVLG': 90, 'OSTK': 52, 'EDN': 207, 'CGAU': 166, 'YPF': 107, 'PAM': 94, 'IOVA': 183, 'NOK': 182, 'SUZ': 186, 'NG': 198, 'SKYW': 50, 'FSM': 86, 'HZNP': 140, 'EBR': 308, 'PRDO': 176, 'MRCY': 42, 'BLDP': 640, 'ENPH': 118, 'MARA': 708, 'CLF': 20, 'GOL': 435, 'SAND': 97, 'EXK': 89, 'GOLD': 21, 'BVN': 21, 'AU': 22, 'MAG': 51, 'IAG': 71, 'SSRM': 47, 'GFI': 267, 'MODN': 30, 'WW': 81, 'SQM': 16, 'IDCC': 12, 'SMTC': 13, 'UPBD': 12, 'CYTK': 100, 'ANGI': 41, 'LULU': 6, 'HIMX': 50, 'WWE': 28, 'AVD': 23, 'BBSI': 7, 'CCRN': 46, 'EXTR': 67, 'TBBK': 25, 'TNDM': 157, 'HALO': 30, 'GERN': 358, 'CLFD': 17, 'EGLE': 5, 'CHRD': 821, 'GOGL': 112, 'SBLK': 161, 'WTI': 59, 'VTLE': 4, 'SAVA': 242, 'GTLS': 10, 'SID': 262, 'BTE': 161, 'TELL': 802, 'CLNE': 71, 'ARCT': 54, 'PDS': 3, 'ATEN': 64, 'STRL': 86, 'CBAY': 305, 'IVT': 11, 'NRP': 13, 'HMY': 238, 'SSYS': 8, 'ARDX': 439, 'SBSW': 130, 'CPRI': 7, 'CEQP': 18, 'NGD': 111, 'GNK': 36, 'LXU': 169, 'CIVI': 12, 'TK': 52, 'AROC': 80, 'BOOT': 49, 'GPRO': 26, 'NMM': 10, 'HBM': 157, 'MRTX': 54, 'PTCT': 42, 'CLMT': 61, 'IMGN': 235, 'QURE': 40, 'CVI': 31, 'RH': 10, 'ISEE': 180, 'RCKT': 46, 'MCRB': 123, 'STGW': 46, 'ITCI': ...
# {'spy': 1766}
# 234000
# valuation: 2159590
# performance: 823%
# benchmark valuation: 715114
# benchmark performance: 206%
# CAGR: 12%
# benchmark CAGR: 6%

# %% [markdown]
# ## Conclusion
# Both strategies beat the benchmark during various periods within 2004 and 2023. Buying the worst performing stock however yield a much better result than buying the top performers.
