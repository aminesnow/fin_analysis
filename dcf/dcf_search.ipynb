# %% [markdown]
# # DCF companies to find deep value

# %% [markdown]
# ## Params

# %%
import math

discount_rate = 0.12
years = 50
maturity = 15 #math.floor(years/2)
discount_threshold = 0.4
ddm_discount_threshold = 0.1
risk_free_rate = 0.03
mkt_return = .08

# %% [markdown]
# ## Searching for undervalued companies

# %%
import json

# read file
with open('yahoo_tickers.json', 'r') as f:
    data=f.read()

# parse file
y_tickers_data = json.loads(data)
y_tickers = list(map(lambda x: x["symbol"], y_tickers_data["quotes"]))

# %%
import yfinance as yf
import pandas as pd
import numpy_financial as npf

def compute_dcf(t):
    print(t)
    try:
        ticker = yf.Ticker(t)
        df = ticker.history(period='1D', interval="1d")

        if len(df) == 0 or "sharesOutstanding" not in ticker.info or ticker.info["sharesOutstanding"] == None:
            return 1, 1, 1

        price = df["Close"][0]
        shares = ticker.info["sharesOutstanding"]
        cash = ticker.balance_sheet.T["Cash"].iloc[0]
        if math.isnan(cash):
            cash = ticker.balance_sheet.T["Cash"].iloc[1]

        netincome_df = ticker.cashflow.T[["Net Income"]]
        netincome_df = netincome_df[netincome_df["Net Income"] > 0]
        netincome_df = netincome_df.sort_values("")
        netincome_df = netincome_df.reset_index()
        
        netincome_df["Growth"] = (netincome_df["Net Income"] - netincome_df["Net Income"].shift())/netincome_df["Net Income"]
        netincome_df = netincome_df.fillna(0).iloc[1:, :][["Net Income", "Growth"]]

        growth = netincome_df["Growth"].mean(axis=0)
        if growth >= 0.3:
            growth = 0.3
        growth_slowdown = growth/2

        # forcast
        for i in range(years):
            row ={"Net Income": netincome_df["Net Income"].iloc[-1] * (growth+1), "Growth": growth}
            rowdf = pd.DataFrame.from_records([row])
            netincome_df = pd.concat([netincome_df, rowdf], ignore_index=True, axis=0)
            
            if i == maturity:
                growth = -growth_slowdown

        netincome_df = netincome_df.iloc[3:, :]
        cashflows = netincome_df["Net Income"].to_list()

        npv = npf.npv(discount_rate, cashflows);
        value = npv + cash
        forcast_price = value/shares

        # DDM
        ddm = 0
        if "dividendRate" in ticker.info and ticker.info["dividendRate"] != None and "beta" in ticker.info:
            exp_future_div = ticker.info["dividendRate"]
            div_growth = 0.03
            MKT_Risk_prem = mkt_return - risk_free_rate
            beta = ticker.info["beta"]
            COE = round(beta * MKT_Risk_prem + risk_free_rate,4)
            ddm = round(exp_future_div/(COE-div_growth),2)
        return forcast_price, price, ddm
        
    except:
        print("skipping {}".format(t))
        return 1, 1, 1

# %%
undervalued = []
undervalued_ddm = []

for t in y_tickers:
    fp, p, d = compute_dcf(t)
    if (fp - p)/p > discount_threshold:
        undervalued.append({"ticker": t, "forcast_price": fp, "current_price": p, "DDM": d})
    if d > p * (1+ddm_discount_threshold):
        undervalued_ddm.append({"ticker": t, "forcast_price": fp, "current_price": p, "DDM": d})
# Out:
# APC.DE
# TL0.DE
# MC.PA
# SAP.DE
# OR.PA
# UNA.AS
# PRX.AS
# ASML.AS
# SAN.PA
# LIN.DE
# SIE.DE
# ABI.BR
# RDSA.AS
# - RDSA.AS: No data found, symbol may be delisted
# R6C3.DE
# - R6C3.DE: No data found, symbol may be delisted
# R6C.DE
# - R6C.DE: No data found, symbol may be delisted
# RDSB.AS
# - RDSB.AS: No data found, symbol may be delisted
# FP.PA
# - FP.PA: No data found, symbol may be delisted
# ENEL.MI
# VOW.DE
# RMS.PA
# VOW3.DE
# ALV.DE
# DTE.DE
# ITX.MC
# KER.PA
# HBC1.DE
# AI.PA
# IBE.MC
# 3CP.F
# BPE5.DE
# SU.PA
# BPE5.F
# BAYN.DE
# AIR.PA
# AIR.DE
# ADS.DE
# MRK.DE
# BAS.DE
# DAI.DE
# - DAI.DE: No data found, symbol may be delisted
# EL.PA
# DPW.DE
# GAZ.DE
# - GAZ.DE: No data found for this date range, symbol may be delisted
# GAZ.F
# - GAZ.F: No data found, symbol may be delisted
# ABR.DE
# BNP.PA
# HEIA.AS
# GEC.DE
# - GEC.DE: No data found for this date range, symbol may be delisted
# DG.PA
# BMW3.DE
# ADYEN.AS
# BMW.DE
# SAF.PA
# AXA.DE
# CS.PA
# DSY.PA
# RACE.MI
# SHL.DE
# REN.AS
# BN.PA
# RI.PA
# PHIA.AS
# HEN3.DE
# HEN.DE
# MUV2.DE
# VNA.DE
# VODI.F
# ISP.MI
# IFX.DE
# IES.DE
# BY6.F
# SAN.MC
# skipping SAN.MC
# BSD2.DE
# ENGI.PA
# DB1.DE
# VIV.PA
# - VIV.PA: CircuitBreaker 'redis' is OPEN and does not permit further calls
# AD.AS
# skipping AD.AS
# INN1.DE
# INGA.AS
# ENI.MI
# EDF.PA
# 8GC.F
# DIM.PA
# EOAN.DE
# FRE.DE
# ORA.PA
# CRG.IR
# CLNX.MC
# ELE.MC
# ACA.PA
# 3CP.SG
# DSM.AS
# STM.MI
# STM.PA
# BEI.DE
# FME.DE
# AMS.MC
# RWE.DE
# N3IA.F
# SRT3.DE
# KRZ.IR
# G.MI
# KBC.BR
# LLD.DE
# FCA.MI
# - FCA.MI: No data found, symbol may be delisted
# NOKIA.PA
# NOA3.DE
# HEIO.AS
# FLTR.IR
# CAP.PA
# BCY.DE
# SGO.PA
# WKL.AS
# LR.PA
# CON.DE
# UCB.BR
# AENA.MC
# ZAL.DE
# JDEP.AS
# DHER.DE
# UCG.MI
# HNR1.DE
# ML.PA
# GRU.F
# TNE5.DE
# TEF.MC
# CCEP.AS
# PAH3.DE
# AKZA.AS
# NTGY.MC
# BBVA.MC
# DBK.DE
# KBX.DE
# DBK.F
# EDP.LS
# FER.MC
# SY1.DE
# DWNI.DE
# TEP.PA
# SGRE.MC
# A5G.IR
# SRG.MI
# BIM.PA
# UG.PA
# - UG.PA: No data found, symbol may be delisted
# HO.PA
# WLN.PA
# RY4C.IR
# - RY4C.IR: No data found, symbol may be delisted
# GRF.MC
# TKWY.AS
# 22UA.F
# KRX.IR
# AMUN.PA
# EN.PA
# EDPR.LS
# TRN.MI
# GBLB.BR
# CABK.MC
# BTQ.DE
# ATL.MI
# ARRD.DE
# CA.PA
# MT.AS
# MTS.MC
# EXO.MI
# EVK.DE
# PUM.DE
# HEI.DE
# VIE.PA
# NN.AS
# EDEN.PA
# ALO.PA
# CPR.MI
# PST.MI
# NEXI.MI
# GLE.PA
# UN01.DE
# REP.MC
# ILD.PA
# - ILD.PA: No data found, symbol may be delisted
# UMI.BR
# SEV.PA
# - SEV.PA: No data found, symbol may be delisted
# BOL.PA
# QIA.DE
# CNHI.MI
# SW.PA
# REC.MI
# skipping REC.MI
# KPN.AS
# LEG.DE
# 8TRA.DE
# UBI.PA
# MONC.MI
# KGX.DE
# ARGX.BR
# JMT.LS
# BVI.PA
# REE.MC
# - REE.MC: No data found for this date range, symbol may be delisted
# ING.PA
# - ING.PA: No data found, symbol may be delisted
# HLAG.DE
# ADP.PA
# INW.MI
# DIA.MI
# BNR.DE
# RAND.AS
# MTX.DE
# AFX.DE
# SOLB.BR
# TMV.DE
# GFC.PA
# TIT.MI
# skipping TIT.MI
# TLX.DE
# TITR.MI
# ATO.PA
# 1COV.DE
# CNP.PA
# - CNP.PA: No data found for this date range, symbol may be delisted
# G24.DE
# FGR.PA
# UTDI.DE
# GLPG.AS
# ABN.AS
# SK3.IR
# AKE.PA
# FBK.MI
# IPN.PA
# GALP.LS
# RCO.PA
# COLR.BR
# NEM.DE
# O2D.DE
# RNO.PA
# ENX.PA
# SK.PA
# AGS.BR
# KN.PA
# - KN.PA: No data found, symbol may be delisted
# PUB.PA
# FR.PA
# US.MI
# LHL.F
# BC8.DE
# AMP.MI
# AT1.DE
# GET.PA
# ORP.PA
# PRY.MI
# DWS.DE
# HFG.DE
# MB.MI
# ACS.MC
# CBK.F
# CBK.DE
# GVNV.AS
# - GVNV.AS: No data found, symbol may be delisted
# VPK.AS
# FDJ.PA
# ELI.BR
# AC.PA
# ASM.AS
# COV.PA
# G1A.DE
# EO.PA
# PROX.BR
# ANA.MC
# PSH.AS
# TEN.MI
# ENG.MC
# URW.AS
# FPE3.DE
# HOT.DE
# WDP.BR
# VAR1.DE
# LHA.DE
# IMCD.AS
# ATC.AS
# - ATC.AS: No data found, symbol may be delisted
# LHA.F
# HLE.DE
# HER.MI
# ATCB.AS
# - ATCB.AS: No data found, symbol may be delisted
# RRTL.DE
# skipping RRTL.DE
# BMED.MI
# MAP.MC
# AGN.AS
# AEND.DE
# SCR.PA
# LXS.DE
# IG.MI
# IAG.MC
# DLG.MI
# ASRNL.AS
# BKIA.MC
# - BKIA.MC: No data found, symbol may be delisted
# COP.DE
# UBI.MI
# - UBI.MI: No data found, symbol may be delisted
# DRI.DE
# - DRI.DE: No data found, symbol may be delisted
# OSR.DE
# - OSR.DE: No data found, symbol may be delisted
# BKT.MC
# WCH.DE
# skipping WCH.DE
# EVD.DE
# RUI.PA
# BZU.MI
# SOI.PA
# PIRC.MI
# SHA.DE
# skipping SHA.DE
# A2A.MI
# SAX.DE
# PLUN.DE
# BZUR.MI
# - BZUR.MI: No data found, symbol may be delisted
# PLUN.F
# TEG.DE
# NEOEN.PA
# skipping NEOEN.PA
# LI.PA
# ALD.PA
# LIGHT.AS
# ACE.MI
# ICAD.PA
# MF.PA
# GYC.DE
# TKA.DE
# REY.MI
# AALB.AS
# TNET.BR
# RF.PA
# MOR.DE
# skipping MOR.DE
# SZU.DE
# RXL.PA
# SESG.PA
# FCC.MC
# EVT.DE
# DEC.PA
# IP.MI
# RHM.DE
# POM.PA
# ERG.MI
# FRA.DE
# MRL.MC
# MAREL.AS
# SOW.DE
# skipping SOW.DE
# SIX2.DE
# LDO.MI
# EBRO.MC
# GTT.PA
# BGN.MI
# B4B.DE
# GXI.DE
# UNI.MI
# COL.MC
# MAS.MC
# - MAS.MC: No data found, symbol may be delisted
# NK.PA
# IMA.MI
# - IMA.MI: No data found, symbol may be delisted
# JUN3.DE
# IRE.MI
# BRE.MI
# SBMO.AS
# GL9.IR
# D7G.F
# BME.MC
# - BME.MC: No data found, symbol may be delisted
# FDR.MC
# VIS.MC
# ZOT.MC
# - ZOT.MC: No data found, symbol may be delisted
# NDA.DE
# PO0.F
# KORI.PA
# DLG.DE
# - DLG.DE: No data found, symbol may be delisted
# FTI.PA
# - FTI.PA: No data found, symbol may be delisted
# GLJ.DE
# ATE.PA
# RKET.DE
# - RKET.DE: No data found, symbol may be delisted
# ELIS.PA
# SPIE.PA
# CO.PA
# skipping CO.PA
# PSM.DE
# skipping PSM.DE
# AT.MI
# - AT.MI: No data found, symbol may be delisted
# FNTN.DE
# MMB.PA
# WAF.DE
# OCI.AS
# BOKA.AS
# AZM.MI
# BAMI.MI
# TUI1.F
# CRBN.AS
# TUI1.DE
# BB.PA
# MS.MI
# - MS.MI: No data found, symbol may be delisted
# SAB.MC
# NEX.PA
# ETL.PA
# SFER.MI
# LOG.MC
# CAP.DE
# - CAP.DE: No data found, symbol may be delisted
# VEON.AS
# BIRG.IR
# APAM.AS
# TLG.DE
# - TLG.DE: No data found, symbol may be delisted
# ENAV.MI
# GVS.MI
# DUE.DE
# ACX.MC
# BESI.AS
# CIE.MC
# SLR.MC
# ADJ.DE
# skipping ADJ.DE
# NOS.LS
# COK.DE
# BC.MI
# PHM.MC
# BPOST.BR
# ALM.MC
# EURN.BR
# SAE.DE
# ARCAD.AS
# ROVI.MC
# skipping ROVI.MC
# NVG.LS
# RWAY.MI
# SPM.MI
# FKR.MI
# - FKR.MI: No data found for this date range, symbol may be delisted
# BOSS.DE
# BAR.BR
# TGYM.MI
# RENE.LS
# NXI.PA
# BMPS.MI
# AF.PA
# PHZ.F
# FLOW.AS
# EKT.MC
# - EKT.MC: No data found, symbol may be delisted
# SANT.DE
# - SANT.DE: No data found for this date range, symbol may be delisted
# FAGR.BR
# MMT.PA
# BFIT.AS
# CE.MI
# BCP.LS
# TWEKA.AS
# CEC.DE
# ABIO.PA
# PNL.AS
# skipping PNL.AS
# ANIM.MI
# CERV.MI
# - CERV.MI: No data found, symbol may be delisted
# IJ8.F
# skipping IJ8.F
# GEST.MC
# CARM.PA
# S92.DE
# JEN.DE
# WAC.DE
# TFI.PA
# JUVE.MI
# HHFA.DE
# NDX1.DE
# skipping NDX1.DE
# DRW3.DE
# A5S.F
# - A5S.F: No data found, symbol may be delisted
# SON.LS
# SCYR.MC
# IDR.MC
# ALFEN.AS
# PSG.MC
# NHH.MC
# CASH.MC
# BPE.MI
# FTK.DE
# TL5.MC
# CE2.DE
# SDF.DE
# AGL.MI
# NIBC.AS
# - NIBC.AS: No data found, symbol may be delisted
# COFA.PA
# AIXA.DE
# ARL.DE
# UNI.MC
# DGD.F
# FAE.MC
# CC1.DE
# VBK.DE
# FCT.MI
# WBD.MI
# ONTEX.BR
# CEM.MI
# DANR.MI
# IPS.PA
# TIP.MI
# APPS.MC
# KIN.BR
# FNAC.PA
# GFG.DE
# MARR.MI
# TOM2.AS
# NOEJ.DE
# PIA.MI
# CASS.MI
# ALTR.LS
# DIC.DE
# EUZ.DE
# HOME.MC
# BPSO.MI
# TNXT.MI
# INS.DE
# ELIOR.PA
# PBB.DE
# skipping PBB.DE
# BFF.MI
# DIA.MC
# DOV.MI
# MITRA.BR
# ADX.MC
# TOD.MI
# HBRN.IR
# - HBRN.IR: No data found for this date range, symbol may be delisted
# SZG.DE
# GRP.IR
# ASC.MI
# MEL.MC
# LBK.MC
# - LBK.MC: No data found, symbol may be delisted
# ACCEL.AS
# IRES.IR
# TTK.DE
# DEQ.DE
# ERA.PA
# UPR.IR
# SLIGR.AS
# DAL.MI
# VLK.AS
# skipping VLK.AS
# PHARM.AS
# DHG.IR
# GBF.DE
# YZA.IR
# - YZA.IR: No data found, symbol may be delisted
# SEM.LS
# BBDB.F
# - BBDB.F: No data found for this date range, symbol may be delisted
# TKTT.PA
# AGFB.BR
# ENC.MC
# GVR.IR
# IR5B.IR
# ALCLS.PA
# DEZ.DE
# BFG.MI
# ILTY.MI
# AB.PA
# 24Y.F
# DOM.MC
# TRE.MC
# MDM.PA
# C5H.IR
# A3M.MC
# ECONB.BR
# BSGR.AS
# RLIA.MC
# BVB.DE
# CIR.MI
# LPK.DE
# CVAL.MI
# - CVAL.MI: No data found, symbol may be delisted
# SRS.MI
# BEN.PA
# AMG.AS
# FFARM.AS
# MERY.PA
# MCPHY.PA
# KCO.DE
# TLGO.MC
# ECMPA.AS
# AR4.DE
# MT.MI
# P6K.F
# - P6K.F: No data found, symbol may be delisted
# IF.MI
# REC.BR
# CGG.PA
# VLA.PA
# ELN.MI
# T7O.IR
# - T7O.IR: No data found, symbol may be delisted
# DBG.PA
# CRI.PA
# OIZ.IR
# skipping OIZ.IR
# TC1.DE
# - TC1.DE: No data found, symbol may be delisted
# PNE3.DE
# WEW.DE
# SGL.DE
# BSS.MI
# AVIO.MI
# AKA.PA
# - AKA.PA: No data found for this date range, symbol may be delisted
# CTT.LS
# IVA.PA
# MDW.PA
# - MDW.PA: No data found, symbol may be delisted
# FILA.MI
# CCAP.DE
# ZIL2.DE
# XFAB.PA
# QDT.PA
# FEY2.F
# NWC.F
# LRE.MC
# LIT.MI
# - LIT.MI: No data found, symbol may be delisted
# IGD.MI
# BRNL.AS
# BAMNB.AS
# ARN.MI
# MAU.PA
# GFT.DE
# MN.MI
# ADV.DE
# RM.MI
# - RM.MI: No data found, symbol may be delisted
# FUR.AS
# SMCP.PA
# DIB.MI
# DEA.MI
# EGL.LS
# PRT.MI
# RCS.MI
# G3U.F
# H24.DE
# - H24.DE: CircuitBreaker 'redis' is OPEN and does not permit further calls
# SMHN.DE
# WHA.AS
# FNM.MI
# TFI.MI
# EDR.MC
# BCART.BR
# RJF.MC
# IPH.PA
# CLA.PA
# ALNOV.PA
# SFQ.DE
# MLM.MI
# - MLM.MI: No data found, symbol may be delisted
# ALCRB.PA
# VMX.PA
# ORDI.AS
# RAL.PA
# GREEN.BR
# UBS.MC
# VK.PA
# skipping VK.PA
# IL0A.IR
# PJM.F
# FM.MI
# ECR.MC
# ASR.MI
# UNIR.MI
# OVS.MI
# LEO.DE
# MIO.IR
# ECNL.MI
# DBV.PA
# F3C.DE
# RWI.AS
# G7P.F
# ACPH.BR
# - ACPH.BR: No data found for this date range, symbol may be delisted
# POXEL.PA
# HDD.DE
# AMP.MC
# SNH.DE
# - SNH.DE: No data found for this date range, symbol may be delisted
# NANO.PA
# CAI.MI
# skipping CAI.MI
# SONC.LS
# - SONC.LS: No data found, symbol may be delisted
# OHL.MC
# - OHL.MC: No data found, symbol may be delisted
# AXS.AS
# skipping AXS.AS
# HEIJM.AS
# B8F.DE
# GEO.MI
# SFL.MI
# QSC.DE
# - QSC.DE: No data found, symbol may be delisted
# SERI.MI
# skipping SERI.MI
# SNH.F
# NXT.MC
# PA8.DE
# GNFT.PA
# SWQ.F
# AVTX.AS
# QC8.F
# DMJ.F
# ORY.MC
# TUB.MC
# K3A.F
# BEST.MI
# CDR.MC
# - CDR.MC: No data found, symbol may be delisted
# ALMED.PA
# - ALMED.PA: No data found, symbol may be delisted
# BT81.F
# LLN.MC
# BST.MI
# EM.MI
# skipping EM.MI
# ETH.MI
# ECX.DE
# PRO.MI
# OLE.MC
# IMS.MI
# ALERS.PA
# ALREW.PA
# BKY.MC
# ZYT.F
# - ZYT.F: No data found, symbol may be delisted
# B5R.F
# COX.PA
# SFPI.PA
# ALSEN.PA
# IKG.MI
# IKGR.MI
# EXM.BR
# TNG.PA
# WDI.F
# - WDI.F: No data found, symbol may be delisted
# WDI.DE
# - WDI.DE: No data found, symbol may be delisted
# DIS.MI
# SO.MI
# MDG1.DE
# TIS.MI
# skipping TIS.MI
# FLO.PA
# EUCAR.PA
# - EUCAR.PA: No data found for this date range, symbol may be delisted
# RN.MI
# ALBIO.PA
# EXSY.MI
# - EXSY.MI: No data found, symbol may be delisted
# 87CA.F
# GUI.PA
# 4BSB.DE
# - 4BSB.DE: No data found, symbol may be delisted
# ALMDT.PA
# SRP.PA
# NUN.F
# PHR.LS
# M8G.DE
# VVY.AS
# ECP.PA
# - ECP.PA: No data found, symbol may be delisted
# SIGHT.PA
# AEF.MI
# 7C8.F
# SSL.MI
# BIO.MC
# - BIO.MC: No data found, symbol may be delisted
# FACE.MC
# PPK.F
# - PPK.F: No data found for this date range, symbol may be delisted
# B1N.F
# ALGAU.PA
# BIM.MI
# - BIM.MI: No data found for this date range, symbol may be delisted
# BFE.MI
# S5L.F
# O7N.F
# 5LA1.F
# ATA.PA
# - ATA.PA: No data found for this date range, symbol may be delisted
# OAC.F
# - OAC.F: No data found, symbol may be delisted
# CATG.PA
# skipping CATG.PA
# YIV.MI
# NAVYA.PA
# MTV.MI
# LR.MI
# ALATF.PA
# - ALATF.PA: No data found, symbol may be delisted
# CY4.MI
# AI.MC
# ALAMG.PA
# BBED.AS
# OPTI.BR
# ACCB.BR
# QM3.F
# VER.MC
# - VER.MC: No data found, symbol may be delisted
# ATH.MI
# - ATH.MI: No data found for this date range, symbol may be delisted
# ALCJ.PA
# LOCAL.PA
# QBT.MC
# - QBT.MC: No data found, symbol may be delisted
# BRI.MI
# ONXEO.PA
# - ONXEO.PA: No data found, symbol may be delisted
# OREGE.PA
# ATY.F
# LUC.F
# ALQGC.PA
# ALTUV.PA
# METEX.PA
# KDS.AS
# - KDS.AS: No data found, symbol may be delisted
# ALBUD.PA
# INC.MI
# POQ.F
# PZQA.IR
# M11.F
# TTG.F
# REB.F
# KEU1.SG
# skipping KEU1.SG
# 26N.F
# - 26N.F: No data found for this date range, symbol may be delisted
# MDF.MC
# TCH.PA
# GG.MI
# Z4RN.F
# - Z4RN.F: No data found, symbol may be delisted
# XTZA.MC
# EEMS.MI
# AST.MI
# - AST.MI: No data found, symbol may be delisted
# TDSA.LS
# IGV.MI
# DU8.F
# ISG.MI
# - ISG.MI: No data found, symbol may be delisted
# ALHYG.PA
# skipping ALHYG.PA
# EOSI.PA
# - EOSI.PA: No data found, symbol may be delisted
# ISGS.MI
# - ISGS.MI: No data found, symbol may be delisted
# FALG.PA
# 2TP2.F
# - 2TP2.F: No data found, symbol may be delisted
# DLE.IR
# G5M.F
# - G5M.F: No data found, symbol may be delisted
# BE.MI
# XPR.MI
# PRL.MI
# PRS.MC
# ALBPS.PA
# MKEA.PA
# EZE.MC
# AU4.F
# 3EZ.F
# UG8K.F
# - UG8K.F: No data found, symbol may be delisted
# BALYO.PA
# AMEBA.PA
# - AMEBA.PA: No data found, symbol may be delisted
# ALVER.PA
# S24.MI
# GAB.MI
# 36G.F
# - 36G.F: No data found for this date range, symbol may be delisted
# ALDRV.PA
# A9KN.F
# - A9KN.F: No data found, symbol may be delisted
# 31R.F
# RZZ.F
# skipping RZZ.F
# PU31.F
# - PU31.F: No data found, symbol may be delisted
# 8FD.F
# CIB.PA
# FARM.MI
# ALEUP.PA
# 5E8.F
# ALPIX.PA
# ALMND.PA
# ALVMG.PA
# 1WZ1.F
# - 1WZ1.F: No data found, symbol may be delisted
# CFN.LS
# ELZ.MC
# 5E8.SG
# I3A1.F
# IPR.LS
# TES.MI
# IP4.F
# EIY2.F
# - EIY2.F: No data found, symbol may be delisted
# INA.LS
# TRG.MC
# MON.MI
# ALNOX.PA
# BO.MI
# SOU.MI
# ALTBG.PA
# GO.MI
# CLE.MI
# ALAGR.PA
# 2I7.F
# RST.MI
# GV.PA
# PF8.F
# ABNX.PA
# ALTER.PA
# ALINS.PA
# ALGEN.PA
# BIA.MI
# FUL.MI
# 1BIA.F
# - 1BIA.F: No data found, symbol may be delisted
# ALDEI.PA
# ALINT.PA
# M8H.DE
# 29H.F
# - 29H.F: No data found, symbol may be delisted
# RD31.F
# GEQ.MI
# HOB.F
# - HOB.F: No data found, symbol may be delisted
# MT1.F
# 2CM2.F
# PROL.PA
# - PROL.PA: No data found for this date range, symbol may be delisted
# YBB.F
# NYR.BR
# NTW.MI
# PVA.MC
# ALNLF.PA
# ALNXT.PA
# skipping ALNXT.PA
# ROOD.AS
# S1N.SG
# 1N9.F
# ALNEV.PA
# R1E.F
# - R1E.F: No data found, symbol may be delisted
# ALKKO.PA
# AGA.MI
# ALDIE.PA
# - ALDIE.PA: No data found, symbol may be delisted
# AW5.F
# - AW5.F: No data found, symbol may be delisted
# ALNN6.PA
# AVT.PA
# NYE.MC
# CIA.MI
# ALENE.PA
# TTT.MI
# - TTT.MI: No data found, symbol may be delisted
# CDG.MI
# ALLEX.PA
# B4T.F
# - B4T.F: No data found, symbol may be delisted
# EPR.MI
# MTF.MI
# B7BA.F
# ALALO.PA
# ALMAK.PA
# SQH.F
# BCM.MI
# - BCM.MI: No data found for this date range, symbol may be delisted
# GECP.PA
# - GECP.PA: No data found, symbol may be delisted
# 2EYA.F
# - 2EYA.F: No data found, symbol may be delisted
# R2F.F
# - R2F.F: No data found, symbol may be delisted
# HM5.F
# COM.MC
# MY3.F
# - MY3.F: No data found, symbol may be delisted
# B7BA.SG
# ALMNG.PA
# JXR.PA
# - JXR.PA: No data found, symbol may be delisted
# ARO.F
# ASIT.BR
# - ASIT.BR: No data found, symbol may be delisted
# 9EG.F
# 8GW.IR
# - 8GW.IR: No data found for this date range, symbol may be delisted
# ORQ1.IR
# - ORQ1.IR: No data found for this date range, symbol may be delisted
# AKI.MC
# - AKI.MC: No data found for this date range, symbol may be delisted
# L6V2.F
# XL5.F
# ALSGD.PA
# 1KZ1.F
# - 1KZ1.F: No data found for this date range, symbol may be delisted
# WTB.F
# - WTB.F: No data found, symbol may be delisted
# FF24.DE
# 3AT.F
# - 3AT.F: No data found for this date range, symbol may be delisted
# MLSEQ.PA
# QCE.HM
# FPN.PA
# - FPN.PA: No data found, symbol may be delisted
# ALACT.PA
# BIE.MI
# VAO.DE
# - VAO.DE: No data found for this date range, symbol may be delisted
# 0BL.F
# BN5.F
# KI.MI
# ALDBT.PA
# ESP.AS
# ALSPW.PA
# 5SO.F
# WMC.MI
# - WMC.MI: No data found for this date range, symbol may be delisted
# KRD.F
# - KRD.F: No data found for this date range, symbol may be delisted
# ALADO.PA
# ALSAF.PA
# ALDR.PA
# ALCYB.PA
# VE.MI
# 3SC.BE
# 1H3.BE
# A9KN.MU
# - A9KN.MU: No data found, symbol may be delisted
# I3A1.SG
# D7G.HM
# BT81.SG
# 1H3.MU
# skipping 1H3.MU
# DAI.SG
# - DAI.SG: No data found for this date range, symbol may be delisted
# DTE.SG
# IFX.SG
# 296.SG
# WYE.SG
# - WYE.SG: No data found, symbol may be delisted
# LTL.BE
# - LTL.BE: No data found, symbol may be delisted
# ARO.SG
# 690D.DE
# skipping 690D.DE
# 26N.SG
# - 26N.SG: No data found for this date range, symbol may be delisted
# AWY.BE
# skipping AWY.BE
# DMJ.SG
# MLFSG.PA
# - MLFSG.PA: No data found for this date range, symbol may be delisted
# R1E.SG
# - R1E.SG: No data found, symbol may be delisted
# LC0A.SG
# 1SZ.SG
# D7G.SG
# PLUN.SG
# GJ4.BE
# WDI.SG
# - WDI.SG: No data found, symbol may be delisted
# MCC.BE
# LYZ1.BE
# 31X.MU
# A5A.F
# - A5A.F: No data found for this date range, symbol may be delisted
# U40.F
# 3P2N.F
# - 3P2N.F: No data found, symbol may be delisted
# I5R.BE
# QM3.SG
# QC8.SG
# WWU.BE
# IJ8.SG
# SNH.DU
# GRF-P.MC
# HM5.SG
# - HM5.SG: No data found for this date range, symbol may be delisted
# D7G.MU
# NWC.SG
# TUI1.SG
# A5S.SG
# - A5S.SG: No data found, symbol may be delisted
# K3A.SG
# MN4.BE
# - MN4.BE: No data found for this date range, symbol may be delisted
# WLN.MU
# - WLN.MU: No data found, symbol may be delisted
# 3O4.BE
# - 3O4.BE: No data found, symbol may be delisted
# LOUD.DE
# - LOUD.DE: No data found for this date range, symbol may be delisted
# VODI.DE
# CRUDP.PA
# skipping CRUDP.PA
# 5LA1.SG
# R1Y.SG
# PU31.SG
# - PU31.SG: No data found, symbol may be delisted
# POH1.DE
# 5CV.F
# FMV.DE
# DU8.SG
# BT81.MU
# HJR.SG
# - HJR.SG: No data found, symbol may be delisted
# PPK.SG
# - PPK.SG: No data found, symbol may be delisted
# NGASP.PA
# BPE5.SG
# 20MP.F
# SNH.SG
# BN5.SG
# CBK.SG
# LHA.SG
# skipping LHA.SG
# N2C.BE
# PO0.SG
# P8W.BE
# DBK.SG
# EOAN.SG

# %%
undervalued
# Out:
# [{'ticker': 'PRX.AS',
#   'forcast_price': 1107.7627441615716,
#   'current_price': 66.6500015258789,
#   'DDM': 6.39},
#  {'ticker': 'ASML.AS',
#   'forcast_price': 867.8947011650886,
#   'current_price': 421.5,
#   'DDM': 70.75},
#  {'ticker': 'VOW.DE',
#   'forcast_price': 552.801798145462,
#   'current_price': 169.6999969482422,
#   'DDM': 0},
#  {'ticker': 'VOW3.DE',
#   'forcast_price': 791.0878984438729,
#   'current_price': 121.08000183105469,
#   'DDM': 0},
#  {'ticker': 'DTE.DE',
#   'forcast_price': 32.512850719882074,
#   'current_price': 19.073999404907227,
#   'DDM': 0},
#  {'ticker': 'HBC1.DE',
#   'forcast_price': 23.00273297902713,
#   'current_price': 6.035999774932861,
#   'DDM': 0},
#  {'ticker': '3CP.F',
#   'forcast_price': 12.571701626257978,
#   'current_price': 1.639799952507019,
#   'DDM': 0},
#  {'ticker': 'BPE5.DE',
#   'forcast_price': 46.835897337058356,
#   'current_price': 4.2845001220703125,
#   'DDM': 0},
#  {'ticker': 'BPE5.F',
#   'forcast_price': 46.835897337058356,
#   'current_price': 4.302499771118164,
#   'DDM': 0},
#  {'ticker': 'BAYN.DE',
#   'forcast_price': 124.73592284916073,
#   'current_price': 56.060001373291016,
#   'DDM': 0},
#  {'ticker': 'AIR.PA',
#   'forcast_price': 651.0434536146935,
#   'current_price': 92.54000091552734,
#   'DDM': 0},
#  {'ticker': 'AIR.DE',
#   'forcast_price': 651.0434536146935,
#   'current_price': 92.55000305175781,
#   'DDM': 0},
#  {'ticker': 'BAS.DE',
#   'forcast_price': 712.2918984033362,
#   'current_price': 39.83000183105469,
#   'DDM': 0},
#  {'ticker': 'EL.PA',
#   'forcast_price': 1.1402051064197846e+20,
#   'current_price': 143.0,
#   'DDM': 0},
#  {'ticker': 'DPW.DE',
#   'forcast_price': 297.86271419386844,
#   'current_price': 35.32500076293945,
#   'DDM': 0},
#  {'ticker': 'ABR.DE',
#   'forcast_price': 47.28239535227324,
#   'current_price': 16.531999588012695,
#   'DDM': 0},
#  {'ticker': 'BNP.PA',
#   'forcast_price': 401.3988161541704,
#   'current_price': 43.52000045776367,
#   'DDM': 0},
#  {'ticker': 'HEIA.AS',
#   'forcast_price': 686.789261912399,
#   'current_price': 90.9000015258789,
#   'DDM': 0},
#  {'ticker': 'BMW3.DE',
#   'forcast_price': 2096.4786232378938,
#   'current_price': 66.5,
#   'DDM': 0},
#  {'ticker': 'BMW.DE',
#   'forcast_price': 200.9059587410363,
#   'current_price': 71.52999877929688,
#   'DDM': 0},
#  {'ticker': 'SAF.PA',
#   'forcast_price': 4.658087297069522e+21,
#   'current_price': 95.36000061035156,
#   'DDM': 0},
#  {'ticker': 'AXA.DE',
#   'forcast_price': 270.1059683215922,
#   'current_price': 20.795000076293945,
#   'DDM': 0},
#  {'ticker': 'CS.PA',
#   'forcast_price': 270.1059683215922,
#   'current_price': 20.809999465942383,
#   'DDM': 0},
#  {'ticker': 'PHIA.AS',
#   'forcast_price': 264.638542009019,
#   'current_price': 20.78499984741211,
#   'DDM': 0},
#  {'ticker': 'ISP.MI',
#   'forcast_price': 2.645505657532518,
#   'current_price': 1.6782000064849854,
#   'DDM': 0},
#  {'ticker': 'IES.DE',
#   'forcast_price': 2.645505657532518,
#   'current_price': 1.6842000484466553,
#   'DDM': 0},
#  {'ticker': 'BY6.F',
#   'forcast_price': 55.55029747711675,
#   'current_price': 39.189998626708984,
#   'DDM': 0},
#  {'ticker': 'BSD2.DE',
#   'forcast_price': 57.25960671091893,
#   'current_price': 2.5304999351501465,
#   'DDM': 0},
#  {'ticker': 'ENGI.PA',
#   'forcast_price': 184.20510560223778,
#   'current_price': 10.331999778747559,
#   'DDM': 0},
#  {'ticker': 'ENI.MI',
#   'forcast_price': 4.844461944605279e+34,
#   'current_price': 10.755999565124512,
#   'DDM': 0},
#  {'ticker': 'EDF.PA',
#   'forcast_price': 418015.2513911971,
#   'current_price': 8.970000267028809,
#   'DDM': 0},
#  {'ticker': '8GC.F',
#   'forcast_price': 44.726434012311,
#   'current_price': 4.770500183105469,
#   'DDM': 0},
#  {'ticker': 'ORA.PA',
#   'forcast_price': 2.2093851532620395e+29,
#   'current_price': 11.031999588012695,
#   'DDM': 0},
#  {'ticker': 'ACA.PA',
#   'forcast_price': 12.898322088789422,
#   'current_price': 8.383000373840332,
#   'DDM': 0},
#  {'ticker': 'STM.MI',
#   'forcast_price': 44.06815107885732,
#   'current_price': 29.364999771118164,
#   'DDM': 0},
#  {'ticker': 'STM.PA',
#   'forcast_price': 44.06815107885732,
#   'current_price': 29.315000534057617,
#   'DDM': 0},
#  {'ticker': 'RWE.DE',
#   'forcast_price': 15184699286.381954,
#   'current_price': 35.650001525878906,
#   'DDM': 0},
#  {'ticker': 'SRT3.DE',
#   'forcast_price': 598.0768531595095,
#   'current_price': 365.70001220703125,
#   'DDM': 0},
#  {'ticker': 'G.MI',
#   'forcast_price': 21.870501416108322,
#   'current_price': 14.704999923706055,
#   'DDM': 0},
#  {'ticker': 'KBC.BR',
#   'forcast_price': 135.06403877432024,
#   'current_price': 50.02000045776367,
#   'DDM': 0},
#  {'ticker': 'LLD.DE',
#   'forcast_price': 1.219495604147529,
#   'current_price': 0.49000000953674316,
#   'DDM': 0},
#  {'ticker': 'NOKIA.PA',
#   'forcast_price': 35.17083728955356,
#   'current_price': 4.45550012588501,
#   'DDM': 0},
#  {'ticker': 'NOA3.DE',
#   'forcast_price': 35.17083728955356,
#   'current_price': 4.456999778747559,
#   'DDM': 0},
#  {'ticker': 'HEIO.AS',
#   'forcast_price': 693.1294675570741,
#   'current_price': 71.69999694824219,
#   'DDM': 0},
#  {'ticker': 'BCY.DE',
#   'forcast_price': 33.408931867524764,
#   'current_price': 1.7649999856948853,
#   'DDM': 0},
#  {'ticker': 'CON.DE',
#   'forcast_price': 869.6207414359246,
#   'current_price': 63.619998931884766,
#   'DDM': 0},
#  {'ticker': 'ZAL.DE',
#   'forcast_price': 119.29867883588574,
#   'current_price': 25.329999923706055,
#   'DDM': 0},
#  {'ticker': 'UCG.MI',
#   'forcast_price': 130.86191580080495,
#   'current_price': 8.833999633789062,
#   'DDM': 0},
#  {'ticker': 'GRU.F',
#   'forcast_price': 3.4612382095243253,
#   'current_price': 2.0385000705718994,
#   'DDM': 0},
#  {'ticker': 'PAH3.DE',
#   'forcast_price': 250.49314645535165,
#   'current_price': 59.939998626708984,
#   'DDM': 0},
#  {'ticker': 'AKZA.AS',
#   'forcast_price': 4.3851355463366705e+20,
#   'current_price': 61.560001373291016,
#   'DDM': 0},
#  {'ticker': 'NTGY.MC',
#   'forcast_price': 153.1755362714073,
#   'current_price': 27.540000915527344,
#   'DDM': 0},
#  {'ticker': 'DBK.DE',
#   'forcast_price': 223.92071488916233,
#   'current_price': 7.71999979019165,
#   'DDM': 0},
#  {'ticker': 'DBK.F',
#   'forcast_price': 223.92071488916233,
#   'current_price': 7.741000175476074,
#   'DDM': 0},
#  {'ticker': 'FER.MC',
#   'forcast_price': 202.27488356269996,
#   'current_price': 24.809999465942383,
#   'DDM': 0},
#  {'ticker': 'A5G.IR',
#   'forcast_price': 44.033590510664986,
#   'current_price': 1.9780000448226929,
#   'DDM': 0},
#  {'ticker': 'SRG.MI',
#   'forcast_price': 12.347303987665883,
#   'current_price': 5.013999938964844,
#   'DDM': 0},
#  {'ticker': 'BIM.PA',
#   'forcast_price': 346.4082368390135,
#   'current_price': 102.44999694824219,
#   'DDM': 0},
#  {'ticker': '22UA.F',
#   'forcast_price': 5014.070788245507,
#   'current_price': 153.89999389648438,
#   'DDM': 0},
#  {'ticker': 'KRX.IR',
#   'forcast_price': 94.97544146223697,
#   'current_price': 56.119998931884766,
#   'DDM': 0},
#  {'ticker': 'AMUN.PA',
#   'forcast_price': 180.03842276255543,
#   'current_price': 49.18000030517578,
#   'DDM': 0},
#  {'ticker': 'EDPR.LS',
#   'forcast_price': 37.44378531419488,
#   'current_price': 23.770000457763672,
#   'DDM': 0},
#  {'ticker': 'CABK.MC',
#   'forcast_price': 15.025546397423243,
#   'current_price': 2.871000051498413,
#   'DDM': 0},
#  {'ticker': 'ARRD.DE',
#   'forcast_price': 1940.6279354461867,
#   'current_price': 20.600000381469727,
#   'DDM': 0},
#  {'ticker': 'CA.PA',
#   'forcast_price': 169.8468632544236,
#   'current_price': 16.80500030517578,
#   'DDM': 0},
#  {'ticker': 'MT.AS',
#   'forcast_price': 1940.6279354461867,
#   'current_price': 20.6299991607666,
#   'DDM': 0},
#  {'ticker': 'MTS.MC',
#   'forcast_price': 1940.6279354461867,
#   'current_price': 20.68000030517578,
#   'DDM': 0},
#  {'ticker': 'EXO.MI',
#   'forcast_price': 909.1910593186743,
#   'current_price': 59.5,
#   'DDM': 0},
#  {'ticker': 'HEI.DE',
#   'forcast_price': 1061.613748636498,
#   'current_price': 43.91999816894531,
#   'DDM': 0},
#  {'ticker': 'VIE.PA',
#   'forcast_price': 5238.215846408563,
#   'current_price': 22.479999542236328,
#   'DDM': 0},
#  {'ticker': 'NN.AS',
#   'forcast_price': 1012.7621675842604,
#   'current_price': 42.47999954223633,
#   'DDM': 0},
#  {'ticker': 'PST.MI',
#   'forcast_price': 19.839467730870616,
#   'current_price': 8.604000091552734,
#   'DDM': 0},
#  {'ticker': 'GLE.PA',
#   'forcast_price': 1050.0235444706252,
#   'current_price': 19.582000732421875,
#   'DDM': 0},
#  {'ticker': 'REP.MC',
#   'forcast_price': 203.5819865984036,
#   'current_price': 12.53499984741211,
#   'DDM': 0},
#  {'ticker': 'QIA.DE',
#   'forcast_price': 269.8944411127545,
#   'current_price': 47.369998931884766,
#   'DDM': 0},
#  {'ticker': 'CNHI.MI',
#   'forcast_price': 153.92875334911204,
#   'current_price': 10.640000343322754,
#   'DDM': 0},
#  {'ticker': 'SW.PA',
#   'forcast_price': 136.24172793837658,
#   'current_price': 73.0199966430664,
#   'DDM': 0},
#  {'ticker': 'KPN.AS',
#   'forcast_price': 36.99316111418435,
#   'current_price': 3.368000030517578,
#   'DDM': 0},
#  {'ticker': 'LEG.DE',
#   'forcast_price': 1014.6629830261915,
#   'current_price': 79.5999984741211,
#   'DDM': 0},
#  {'ticker': '8TRA.DE',
#   'forcast_price': 111.83732174201582,
#   'current_price': 13.539999961853027,
#   'DDM': 0},
#  {'ticker': 'UBI.PA',
#   'forcast_price': 111.81696848645443,
#   'current_price': 42.7400016784668,
#   'DDM': 0},
#  {'ticker': 'HLAG.DE',
#   'forcast_price': 6135.369548665121,
#   'current_price': 250.1999969482422,
#   'DDM': 0},
#  {'ticker': 'DIA.MI',
#   'forcast_price': 273.5815422645887,
#   'current_price': 134.39999389648438,
#   'DDM': 0},
#  {'ticker': 'GFC.PA',
#   'forcast_price': 110622000864111.36,
#   'current_price': 87.69999694824219,
#   'DDM': 0},
#  {'ticker': 'TLX.DE',
#   'forcast_price': 72.94569177702418,
#   'current_price': 34.81999969482422,
#   'DDM': 0},
#  {'ticker': 'ATO.PA',
#   'forcast_price': 32.025761294891645,
#   'current_price': 11.279999732971191,
#   'DDM': 0},
#  {'ticker': 'G24.DE',
#   'forcast_price': 1.0294300799933175e+36,
#   'current_price': 52.779998779296875,
#   'DDM': 0},
#  {'ticker': 'UTDI.DE',
#   'forcast_price': 59.57223386446563,
#   'current_price': 26.75,
#   'DDM': 0},
#  {'ticker': 'ABN.AS',
#   'forcast_price': 225.17749320780936,
#   'current_price': 10.074999809265137,
#   'DDM': 0},
#  {'ticker': 'SK3.IR',
#   'forcast_price': 312.55790413135844,
#   'current_price': 31.0,
#   'DDM': 0},
#  {'ticker': 'AKE.PA',
#   'forcast_price': 138.5544431118123,
#   'current_price': 87.30000305175781,
#   'DDM': 0},
#  {'ticker': 'FBK.MI',
#   'forcast_price': 20.104801516897428,
#   'current_price': 11.5649995803833,
#   'DDM': 0},
#  {'ticker': 'IPN.PA',
#   'forcast_price': 934.5364185240645,
#   'current_price': 91.9000015258789,
#   'DDM': 0},
#  {'ticker': 'O2D.DE',
#   'forcast_price': 8.7118010863508,
#   'current_price': 2.736999988555908,
#   'DDM': 0},
#  {'ticker': 'RNO.PA',
#   'forcast_price': 436.6133633103027,
#   'current_price': 22.665000915527344,
#   'DDM': 0},
#  {'ticker': 'ENX.PA',
#   'forcast_price': 172.11278131299574,
#   'current_price': 76.81999969482422,
#   'DDM': 0},
#  {'ticker': 'FR.PA',
#   'forcast_price': 95.42210605476578,
#   'current_price': 17.209999084472656,
#   'DDM': 0},
#  {'ticker': 'LHL.F',
#   'forcast_price': 12.11810943259969,
#   'current_price': 0.8930000066757202,
#   'DDM': 0},
#  {'ticker': 'BC8.DE',
#   'forcast_price': 64.62167207002311,
#   'current_price': 38.5,
#   'DDM': 0},
#  {'ticker': 'ORP.PA',
#   'forcast_price': 50.6919812626662,
#   'current_price': 24.59000015258789,
#   'DDM': 0},
#  {'ticker': 'PRY.MI',
#   'forcast_price': 59.46157075937945,
#   'current_price': 25.90999984741211,
#   'DDM': 0},
#  {'ticker': 'DWS.DE',
#   'forcast_price': 198.53237969296308,
#   'current_price': 24.81999969482422,
#   'DDM': 0},
#  {'ticker': 'HFG.DE',
#   'forcast_price': 10127573458.625336,
#   'current_price': 33.15999984741211,
#   'DDM': 0},
#  {'ticker': 'ACS.MC',
#   'forcast_price': 209.455297858856,
#   'current_price': 20.790000915527344,
#   'DDM': 0},
#  {'ticker': 'CBK.F',
#   'forcast_price': 48.25791491196143,
#   'current_price': 5.829999923706055,
#   'DDM': 0},
#  {'ticker': 'CBK.DE',
#   'forcast_price': 48.25791491196143,
#   'current_price': 5.7779998779296875,
#   'DDM': 0},
#  {'ticker': 'AC.PA',
#   'forcast_price': 44.65913694121553,
#   'current_price': 25.68000030517578,
#   'DDM': 0},
#  {'ticker': 'ASM.AS',
#   'forcast_price': 878.4736345509968,
#   'current_price': 207.39999389648438,
#   'DDM': 0},
#  {'ticker': 'G1A.DE',
#   'forcast_price': 205.77207813609758,
#   'current_price': 33.08000183105469,
#   'DDM': 0},
#  {'ticker': 'EO.PA',
#   'forcast_price': 35.83674345519124,
#   'current_price': 15.710000038146973,
#   'DDM': 0},
#  {'ticker': 'PSH.AS',
#   'forcast_price': 1452.39597107332,
#   'current_price': 28.700000762939453,
#   'DDM': 0},
#  {'ticker': 'TEN.MI',
#   'forcast_price': 110.2192033017443,
#   'current_price': 11.104999542236328,
#   'DDM': 0},
#  {'ticker': 'HOT.DE',
#   'forcast_price': 422.54244893351023,
#   'current_price': 45.43000030517578,
#   'DDM': 0},
#  {'ticker': 'WDP.BR',
#   'forcast_price': 270.31512047169974,
#   'current_price': 30.360000610351562,
#   'DDM': 0},
#  {'ticker': 'VAR1.DE',
#   'forcast_price': 369.4387172505564,
#   'current_price': 78.55999755859375,
#   'DDM': 0},
#  {'ticker': 'HLE.DE',
#   'forcast_price': 389.2390615519525,
#   'current_price': 64.0999984741211,
#   'DDM': 0},
#  {'ticker': 'BMED.MI',
#   'forcast_price': 52.25838122616702,
#   'current_price': 6.078000068664551,
#   'DDM': 0},
#  {'ticker': 'MAP.MC',
#   'forcast_price': 5.810938364078656,
#   'current_price': 1.6180000305175781,
#   'DDM': 0},
#  {'ticker': 'AGN.AS',
#   'forcast_price': 1.601282322011462e+40,
#   'current_price': 3.8940000534057617,
#   'DDM': 0},
#  {'ticker': 'AEND.DE',
#   'forcast_price': 1.601282322011462e+40,
#   'current_price': 3.9100000858306885,
#   'DDM': 0},
#  {'ticker': 'SCR.PA',
#   'forcast_price': 31.06533380228828,
#   'current_price': 18.924999237060547,
#   'DDM': 0},
#  {'ticker': 'DLG.MI',
#   'forcast_price': 62.82676870201015,
#   'current_price': 17.8700008392334,
#   'DDM': 0},
#  {'ticker': 'ASRNL.AS',
#   'forcast_price': 92.64098628102599,
#   'current_price': 37.86000061035156,
#   'DDM': 0},
#  {'ticker': 'BKT.MC',
#   'forcast_price': 41.21571488886276,
#   'current_price': 5.056000232696533,
#   'DDM': 0},
#  {'ticker': 'EVD.DE',
#   'forcast_price': 118.10086943026513,
#   'current_price': 50.20000076293945,
#   'DDM': 0},
#  {'ticker': 'PIRC.MI',
#   'forcast_price': 2.2106492203702155e+22,
#   'current_price': 3.865999937057495,
#   'DDM': 0},
#  {'ticker': 'A2A.MI',
#   'forcast_price': 3.8775072600097564,
#   'current_price': 1.2209999561309814,
#   'DDM': 0},
#  {'ticker': 'TEG.DE',
#   'forcast_price': 46.71953701246144,
#   'current_price': 10.770000457763672,
#   'DDM': 0},
#  {'ticker': 'LI.PA',
#   'forcast_price': 227.55182917986932,
#   'current_price': 18.25,
#   'DDM': 0},
#  {'ticker': 'ALD.PA',
#   'forcast_price': 46.97597266472599,
#   'current_price': 10.5,
#   'DDM': 0},
#  {'ticker': 'LIGHT.AS',
#   'forcast_price': 85.38718647642307,
#   'current_price': 31.40999984741211,
#   'DDM': 0},
#  {'ticker': 'ACE.MI',
#   'forcast_price': 22.547006935971982,
#   'current_price': 14.119999885559082,
#   'DDM': 0},
#  {'ticker': 'MF.PA',
#   'forcast_price': 2879.7507811361415,
#   'current_price': 79.8499984741211,
#   'DDM': 0},
#  {'ticker': 'GYC.DE',
#   'forcast_price': 34.864585375487415,
#   'current_price': 13.210000038146973,
#   'DDM': 0},
#  {'ticker': 'TNET.BR',
#   'forcast_price': 86.56840312557922,
#   'current_price': 18.93000030517578,
#   'DDM': 0},
#  {'ticker': 'RF.PA',
#   'forcast_price': 2459.6997038395116,
#   'current_price': 59.70000076293945,
#   'DDM': 0},
#  {'ticker': 'RXL.PA',
#   'forcast_price': 232.96991943174834,
#   'current_price': 14.104999542236328,
#   'DDM': 0},
#  {'ticker': 'SESG.PA',
#   'forcast_price': 97.87688914735132,
#   'current_price': 7.826000213623047,
#   'DDM': 0},
#  {'ticker': 'FCC.MC',
#   'forcast_price': 66.82275587476583,
#   'current_price': 9.34000015258789,
#   'DDM': 0},
#  {'ticker': 'EVT.DE',
#   'forcast_price': 426289.94942729117,
#   'current_price': 25.1299991607666,
#   'DDM': 0},
#  {'ticker': 'RHM.DE',
#   'forcast_price': 818.8217652023079,
#   'current_price': 186.60000610351562,
#   'DDM': 0},
#  {'ticker': 'POM.PA',
#   'forcast_price': 108.93314100473532,
#   'current_price': 15.4399995803833,
#   'DDM': 0},
#  {'ticker': 'FRA.DE',
#   'forcast_price': 134.55280377803956,
#   'current_price': 37.900001525878906,
#   'DDM': 0},
#  {'ticker': 'MRL.MC',
#   'forcast_price': 2667328413182878.5,
#   'current_price': 9.119999885559082,
#   'DDM': 0},
#  {'ticker': 'SIX2.DE',
#   'forcast_price': 1225.3688890858905,
#   'current_price': 103.5,
#   'DDM': 0},
#  {'ticker': 'EBRO.MC',
#   'forcast_price': 52.24503177314399,
#   'current_price': 16.0,
#   'DDM': 0},
#  {'ticker': 'BGN.MI',
#   'forcast_price': 113.41428407412775,
#   'current_price': 25.920000076293945,
#   'DDM': 0},
#  {'ticker': 'UNI.MI',
#   'forcast_price': 14.500153800918127,
#   'current_price': 4.125,
#   'DDM': 0},
#  {'ticker': 'COL.MC',
#   'forcast_price': 3.0142870599587292e+90,
#   'current_price': 5.909999847412109,
#   'DDM': 0},
#  {'ticker': 'NK.PA',
#   'forcast_price': 63185176.719975546,
#   'current_price': 27.780000686645508,
#   'DDM': 0},
#  {'ticker': 'JUN3.DE',
#   'forcast_price': 112.17324915363662,
#   'current_price': 22.100000381469727,
#   'DDM': 0},
#  {'ticker': 'SBMO.AS',
#   'forcast_price': 28.243074475623303,
#   'current_price': 12.079999923706055,
#   'DDM': 0},
#  {'ticker': 'FDR.MC',
#   'forcast_price': 157.30811459668243,
#   'current_price': 18.5,
#   'DDM': 0},
#  {'ticker': 'NDA.DE',
#   'forcast_price': 331.4568059180856,
#   'current_price': 60.880001068115234,
#   'DDM': 0},
#  {'ticker': 'ELIS.PA',
#   'forcast_price': 3.4142238151166106e+49,
#   'current_price': 13.170000076293945,
#   'DDM': 0},
#  {'ticker': 'OCI.AS',
#   'forcast_price': 328.43676775287037,
#   'current_price': 27.8799991607666,
#   'DDM': 0},
#  {'ticker': 'BOKA.AS',
#   'forcast_price': 143.51184497774062,
#   'current_price': 32.0,
#   'DDM': 0},
#  {'ticker': 'BAMI.MI',
#   'forcast_price': 1.3929960539163097e+42,
#   'current_price': 2.440000057220459,
#   'DDM': 0},
#  {'ticker': 'SAB.MC',
#   'forcast_price': 5.040835907234293e+91,
#   'current_price': 0.6492000222206116,
#   'DDM': 0},
#  {'ticker': 'NEX.PA',
#   'forcast_price': 465.3782575471064,
#   'current_price': 76.1500015258789,
#   'DDM': 0},
#  {'ticker': 'SFER.MI',
#   'forcast_price': 58.27144314277769,
#   'current_price': 14.640000343322754,
#   'DDM': 0},
#  {'ticker': 'VEON.AS',
#   'forcast_price': 46.7490850110637,
#   'current_price': 0.6000000238418579,
#   'DDM': 0},
#  {'ticker': 'BIRG.IR',
#   'forcast_price': 143.23130137838788,
#   'current_price': 5.702000141143799,
#   'DDM': 0},
#  {'ticker': 'APAM.AS',
#   'forcast_price': 134.24683648437684,
#   'current_price': 25.469999313354492,
#   'DDM': 0},
#  {'ticker': 'GVS.MI',
#   'forcast_price': 27.531106536275264,
#   'current_price': 8.274999618530273,
#   'DDM': 0},
#  {'ticker': 'DUE.DE',
#   'forcast_price': 150.00639452788712,
#   'current_price': 21.299999237060547,
#   'DDM': 0},
#  {'ticker': 'ACX.MC',
#   'forcast_price': 254.40406263247684,
#   'current_price': 8.168000221252441,
#   'DDM': 0},
#  {'ticker': 'BESI.AS',
#   'forcast_price': 68.49458067297564,
#   'current_price': 43.68000030517578,
#   'DDM': 0},
#  {'ticker': 'COK.DE',
#   'forcast_price': 852.3786634808777,
#   'current_price': 31.219999313354492,
#   'DDM': 0},
#  {'ticker': 'BC.MI',
#   'forcast_price': 93.95454891118175,
#   'current_price': 43.97999954223633,
#   'DDM': 0},
#  {'ticker': 'PHM.MC',
#   'forcast_price': 609.8720816374256,
#   'current_price': 67.12000274658203,
#   'DDM': 0},
#  {'ticker': 'BPOST.BR',
#   'forcast_price': 152.54210676681657,
#   'current_price': 5.494999885559082,
#   'DDM': 0},
#  {'ticker': 'ARCAD.AS',
#   'forcast_price': 229.49791981027948,
#   'current_price': 32.060001373291016,
#   'DDM': 0},
#  {'ticker': 'BOSS.DE',
#   'forcast_price': 238.898829219266,
#   'current_price': 50.220001220703125,
#   'DDM': 0},
#  {'ticker': 'NXI.PA',
#   'forcast_price': 39.61549744454864,
#   'current_price': 25.700000762939453,
#   'DDM': 0},
#  {'ticker': 'BMPS.MI',
#   'forcast_price': 39.598672340582745,
#   'current_price': 0.46299999952316284,
#   'DDM': 0},
#  {'ticker': 'MMT.PA',
#   'forcast_price': 52.18823266929604,
#   'current_price': 13.869999885559082,
#   'DDM': 0},
#  {'ticker': 'CE.MI',
#   'forcast_price': 38.676427534415204,
#   'current_price': 5.170000076293945,
#   'DDM': 0},
#  {'ticker': 'CEC.DE',
#   'forcast_price': 81.1599898559078,
#   'current_price': 2.4040000438690186,
#   'DDM': 0},
#  {'ticker': 'ANIM.MI',
#   'forcast_price': 31.683004139204527,
#   'current_price': 3.2100000381469727,
#   'DDM': 0},
#  {'ticker': 'GEST.MC',
#   'forcast_price': 34.47366722540301,
#   'current_price': 3.049999952316284,
#   'DDM': 0},
#  {'ticker': 'CARM.PA',
#   'forcast_price': 157.17270498210848,
#   'current_price': 13.899999618530273,
#   'DDM': 0},
#  {'ticker': 'WAC.DE',
#   'forcast_price': 30556.208532704124,
#   'current_price': 17.110000610351562,
#   'DDM': 0},
#  {'ticker': 'DRW3.DE',
#   'forcast_price': 286.07321096770886,
#   'current_price': 51.70000076293945,
#   'DDM': 0},
#  {'ticker': 'IDR.MC',
#   'forcast_price': 103.02985555927837,
#   'current_price': 8.9350004196167,
#   'DDM': 0},
#  {'ticker': 'PSG.MC',
#   'forcast_price': 956817448.6006906,
#   'current_price': 1.6089999675750732,
#   'DDM': 0},
#  {'ticker': 'CASH.MC',
#   'forcast_price': 679732769409050.9,
#   'current_price': 0.6100000143051147,
#   'DDM': 0},
#  {'ticker': 'BPE.MI',
#   'forcast_price': 3.605742146836908,
#   'current_price': 1.4184999465942383,
#   'DDM': 0},
#  {'ticker': 'FTK.DE',
#   'forcast_price': 34.61946232098242,
#   'current_price': 9.130000114440918,
#   'DDM': 0},
#  {'ticker': 'SDF.DE',
#   'forcast_price': 1840.8956955473868,
#   'current_price': 19.43000030517578,
#   'DDM': 0},
#  {'ticker': 'COFA.PA',
#   'forcast_price': 17.29061110491765,
#   'current_price': 9.5649995803833,
#   'DDM': 0},
#  {'ticker': 'UNI.MC',
#   'forcast_price': 2.950288990059006,
#   'current_price': 0.815500020980835,
#   'DDM': 0},
#  {'ticker': 'FAE.MC',
#   'forcast_price': 8.69219694605932,
#   'current_price': 3.9100000858306885,
#   'DDM': 0},
#  {'ticker': 'VBK.DE',
#   'forcast_price': 175.69550213313084,
#   'current_price': 46.63999938964844,
#   'DDM': 0},
#  {'ticker': 'FCT.MI',
#   'forcast_price': 2.2450100080429536,
#   'current_price': 0.503000020980835,
#   'DDM': 0},
#  {'ticker': 'DANR.MI',
#   'forcast_price': 71.1501277573224,
#   'current_price': 12.779999732971191,
#   'DDM': 0},
#  {'ticker': 'IPS.PA',
#   'forcast_price': 124.95687282667822,
#   'current_price': 44.20000076293945,
#   'DDM': 0},
#  {'ticker': 'TIP.MI',
#   'forcast_price': 5.7565415286655265e+78,
#   'current_price': 7.480000019073486,
#   'DDM': 0},
#  {'ticker': 'APPS.MC',
#   'forcast_price': 27.86253052755414,
#   'current_price': 6.215000152587891,
#   'DDM': 0},
#  {'ticker': 'FNAC.PA',
#   'forcast_price': 5.573612316270471e+61,
#   'current_price': 39.5,
#   'DDM': 0},
#  {'ticker': 'MARR.MI',
#   'forcast_price': 65.9548846748648,
#   'current_price': 12.65999984741211,
#   'DDM': 0},
#  {'ticker': 'NOEJ.DE',
#   'forcast_price': 2.4534924468266924e+16,
#   'current_price': 21.040000915527344,
#   'DDM': 0},
#  {'ticker': 'PIA.MI',
#   'forcast_price': 3.4111890629758888,
#   'current_price': 2.2139999866485596,
#   'DDM': 0},
#  {'ticker': 'EUZ.DE',
#   'forcast_price': 87.79036338012531,
#   'current_price': 34.380001068115234,
#   'DDM': 0},
#  {'ticker': 'HOME.MC',
#   'forcast_price': 85.90147058054413,
#   'current_price': 11.199999809265137,
#   'DDM': 0},
#  {'ticker': 'BPSO.MI',
#   'forcast_price': 34.25418929672349,
#   'current_price': 3.2039999961853027,
#   'DDM': 0},
#  {'ticker': 'INS.DE',
#   'forcast_price': 53.948442647824294,
#   'current_price': 10.34000015258789,
#   'DDM': 0},
#  {'ticker': 'BFF.MI',
#   'forcast_price': 44.08257854156912,
#   'current_price': 6.309999942779541,
#   'DDM': 0},
#  {'ticker': 'DOV.MI',
#   'forcast_price': 37.55613442162136,
#   'current_price': 5.46999979019165,
#   'DDM': 0},
#  {'ticker': 'ADX.MC',
#   'forcast_price': 53040196565.727234,
#   'current_price': 1.1349999904632568,
#   'DDM': 0},
#  {'ticker': 'SZG.DE',
#   'forcast_price': 1281.256871702066,
#   'current_price': 21.479999542236328,
#   'DDM': 0},
#  {'ticker': 'ASC.MI',
#   'forcast_price': 10629894244.229406,
#   'current_price': 2.8499999046325684,
#   'DDM': 0},
#  {'ticker': 'ACCEL.AS',
#   'forcast_price': 287950.8412923009,
#   'current_price': 57.650001525878906,
#   'DDM': 0},
#  {'ticker': 'DEQ.DE',
#   'forcast_price': 119.79107692195068,
#   'current_price': 22.260000228881836,
#   'DDM': 0},
#  {'ticker': 'ERA.PA',
#   'forcast_price': 1258.3192783456268,
#   'current_price': 85.55000305175781,
#   'DDM': 0},
#  {'ticker': 'UPR.IR',
#   'forcast_price': 21.06158395280818,
#   'current_price': 3.125,
#   'DDM': 0},
#  {'ticker': 'GBF.DE',
#   'forcast_price': 387.97029952888533,
#   'current_price': 29.299999237060547,
#   'DDM': 0},
#  {'ticker': 'SEM.LS',
#   'forcast_price': 45.98636610529437,
#   'current_price': 12.920000076293945,
#   'DDM': 0},
#  {'ticker': 'TKTT.PA',
#   'forcast_price': 30.425869381578025,
#   'current_price': 12.819999694824219,
#   'DDM': 0},
#  {'ticker': 'GVR.IR',
#   'forcast_price': 5.9139841802349995,
#   'current_price': 0.9390000104904175,
#   'DDM': 0},
#  {'ticker': 'DEZ.DE',
#   'forcast_price': 37.587656625590036,
#   'current_price': 3.696000099182129,
#   'DDM': 0},
#  {'ticker': 'ILTY.MI',
#   'forcast_price': 104.11628805451822,
#   'current_price': 9.954999923706055,
#   'DDM': 0},
#  {'ticker': 'MDM.PA',
#   'forcast_price': 3.2465496168929737e+44,
#   'current_price': 8.800000190734863,
#   'DDM': 0},
#  {'ticker': 'ECONB.BR',
#   'forcast_price': 13.031298348832477,
#   'current_price': 3.0450000762939453,
#   'DDM': 0},
#  {'ticker': 'RLIA.MC',
#   'forcast_price': 2.8492919911123834e+29,
#   'current_price': 0.949999988079071,
#   'DDM': 0},
#  {'ticker': 'CIR.MI',
#   'forcast_price': 1.9415270749721734,
#   'current_price': 0.4025000035762787,
#   'DDM': 0},
#  {'ticker': 'AMG.AS',
#   'forcast_price': 62.11816028102172,
#   'current_price': 21.799999237060547,
#   'DDM': 0},
#  {'ticker': 'KCO.DE',
#   'forcast_price': 732.6672368445984,
#   'current_price': 7.425000190734863,
#   'DDM': 0},
#  {'ticker': 'TLGO.MC',
#   'forcast_price': 28.506531671014326,
#   'current_price': 3.130000114440918,
#   'DDM': 0},
#  {'ticker': 'ECMPA.AS',
#   'forcast_price': 9.329729610181962e+24,
#   'current_price': 19.81999969482422,
#   'DDM': 0},
#  {'ticker': 'AR4.DE',
#   'forcast_price': 566.9670809339143,
#   'current_price': 20.139999389648438,
#   'DDM': 0},
#  {'ticker': 'ELN.MI',
#   'forcast_price': 31.448726473648787,
#   'current_price': 12.869999885559082,
#   'DDM': 0},
#  {'ticker': 'PNE3.DE',
#   'forcast_price': 40.79434706292101,
#   'current_price': 13.460000038146973,
#   'DDM': 0},
#  {'ticker': 'WEW.DE',
#   'forcast_price': 72.38589605960425,
#   'current_price': 7.019999980926514,
#   'DDM': 0},
#  {'ticker': 'SGL.DE',
#   'forcast_price': 74.56027304835128,
#   'current_price': 5.864999771118164,
#   'DDM': 0},
#  {'ticker': 'BSS.MI',
#   'forcast_price': 4965124.449130541,
#   'current_price': 12.479999542236328,
#   'DDM': 0},
#  {'ticker': 'CTT.LS',
#   'forcast_price': 8.729214232339368,
#   'current_price': 3.009999990463257,
#   'DDM': 0},
#  {'ticker': 'ZIL2.DE',
#   'forcast_price': 127044300379.93393,
#   'current_price': 7.110000133514404,
#   'DDM': 0},
#  {'ticker': 'XFAB.PA',
#   'forcast_price': 77.73060528700464,
#   'current_price': 5.914999961853027,
#   'DDM': 0},
#  {'ticker': 'NWC.F',
#   'forcast_price': 245.95707463954164,
#   'current_price': 0.8669999837875366,
#   'DDM': 0},
#  {'ticker': 'LRE.MC',
#   'forcast_price': 40.13383886388478,
#   'current_price': 4.730000019073486,
#   'DDM': 0},
#  {'ticker': 'IGD.MI',
#   'forcast_price': 56.76902668367984,
#   'current_price': 3.4049999713897705,
#   'DDM': 0},
#  {'ticker': 'BAMNB.AS',
#   'forcast_price': 12.524773955031643,
#   'current_price': 2.190000057220459,
#   'DDM': 0},
#  {'ticker': 'ARN.MI',
#   'forcast_price': 108.76490636527875,
#   'current_price': 34.29999923706055,
#   'DDM': 0},
#  {'ticker': 'MAU.PA',
#   'forcast_price': 72.78976570315909,
#   'current_price': 3.9000000953674316,
#   'DDM': 0},
#  {'ticker': 'MN.MI',
#   'forcast_price': 20.376173612495244,
#   'current_price': 1.690000057220459,
#   'DDM': 0},
#  {'ticker': 'ADV.DE',
#   'forcast_price': 140.07448074218146,
#   'current_price': 16.790000915527344,
#   'DDM': 0},
#  {'ticker': 'FUR.AS',
#   'forcast_price': 82.76011773927462,
#   'current_price': 10.890000343322754,
#   'DDM': 0},
#  {'ticker': 'SMCP.PA',
#   'forcast_price': 39.06088687598976,
#   'current_price': 4.9079999923706055,
#   'DDM': 0},
#  {'ticker': 'DIB.MI',
#   'forcast_price': 267.4327208655877,
#   'current_price': 24.81999969482422,
#   'DDM': 0},
#  {'ticker': 'DEA.MI',
#   'forcast_price': 5.360519950834155,
#   'current_price': 1.0740000009536743,
#   'DDM': 0},
#  {'ticker': 'EGL.LS',
#   'forcast_price': 9.963432541634994,
#   'current_price': 1.2039999961853027,
#   'DDM': 0},
#  {'ticker': 'PRT.MI',
#   'forcast_price': 115.45461163913907,
#   'current_price': 6.724999904632568,
#   'DDM': 0},
#  {'ticker': 'SMHN.DE',
#   'forcast_price': 101.56771843638202,
#   'current_price': 12.779999732971191,
#   'DDM': 0},
#  {'ticker': 'FNM.MI',
#   'forcast_price': 2.313582745740732,
#   'current_price': 0.4284999966621399,
#   'DDM': 0},
#  {'ticker': 'TFI.MI',
#   'forcast_price': 1.750353393986868,
#   'current_price': 0.5540000200271606,
#   'DDM': 0},
#  {'ticker': 'CLA.PA',
#   'forcast_price': 28.796676315181788,
#   'current_price': 3.492000102996826,
#   'DDM': 0},
#  {'ticker': 'ALCRB.PA',
#   'forcast_price': 49.31510401001125,
#   'current_price': 28.020000457763672,
#   'DDM': 0},
#  {'ticker': 'VMX.PA',
#   'forcast_price': 5.60828697637984,
#   'current_price': 0.7070000171661377,
#   'DDM': 0},
#  {'ticker': 'ORDI.AS',
#   'forcast_price': 31.58685075738363,
#   'current_price': 4.53000020980835,
#   'DDM': 0},
#  {'ticker': 'RAL.PA',
#   'forcast_price': 39.335626315758894,
#   'current_price': 2.8499999046325684,
#   'DDM': 0},
#  {'ticker': 'UBS.MC',
#   'forcast_price': 0.2199577288331337,
#   'current_price': 0.010999999940395355,
#   'DDM': 0},
#  {'ticker': 'PJM.F',
#   'forcast_price': 6.363192075733194e+34,
#   'current_price': 0.0044999998062849045,
#   'DDM': 0},
#  {'ticker': 'FM.MI',
#   'forcast_price': 75.11789235802269,
#   'current_price': 2.759999990463257,
#   'DDM': 0},
#  {'ticker': 'UNIR.MI',
#   'forcast_price': 323.00513210467756,
#   'current_price': 13.170000076293945,
#   'DDM': 0},
#  {'ticker': 'ECNL.MI',
#   'forcast_price': 8.948208211275946e+25,
#   'current_price': 6.119999885559082,
#   'DDM': 0},
#  {'ticker': 'RWI.AS',
#   'forcast_price': 17.001895757970473,
#   'current_price': 8.859999656677246,
#   'DDM': 0},
#  {'ticker': 'AMP.MC',
#   'forcast_price': 4.515806744327259e+23,
#   'current_price': 0.19259999692440033,
#   'DDM': 0},
#  {'ticker': 'HEIJM.AS',
#   'forcast_price': 192.6633867625674,
#   'current_price': 10.5,
#   'DDM': 0},
#  {'ticker': 'B8F.DE',
#   'forcast_price': 79.82821750760479,
#   'current_price': 1.1399999856948853,
#   'DDM': 0},
#  {'ticker': 'SFL.MI',
#   'forcast_price': 6.308739880031877,
#   'current_price': 1.152999997138977,
#   'DDM': 0},
#  {'ticker': 'SNH.F',
#   'forcast_price': 0.25135423704210996,
#   'current_price': 0.14499999582767487,
#   'DDM': 0},
#  {'ticker': 'GNFT.PA',
#   'forcast_price': 164.77988668398194,
#   'current_price': 3.1760001182556152,
#   'DDM': 0},
#  {'ticker': 'SWQ.F',
#   'forcast_price': 0.513770382639565,
#   'current_price': 0.08389999717473984,
#   'DDM': 0},
#  {'ticker': 'K3A.F',
#   'forcast_price': 0.6212262854158126,
#   'current_price': 0.2248000055551529,
#   'DDM': 0},
#  {'ticker': 'BEST.MI',
#   'forcast_price': 5.68216249578377,
#   'current_price': 3.3499999046325684,
#   'DDM': 0},
#  {'ticker': 'LLN.MC',
#   'forcast_price': 8.220033980339746,
#   'current_price': 2.6500000953674316,
#   'DDM': 0},
#  {'ticker': 'BST.MI',
#   'forcast_price': 4.0044027912525175,
#   'current_price': 1.5640000104904175,
#   'DDM': 0},
#  {'ticker': 'PRO.MI',
#   'forcast_price': 2.1505491219172472,
#   'current_price': 0.19699999690055847,
#   'DDM': 0},
#  {'ticker': 'OLE.MC',
#   'forcast_price': 1.5886107943954081e+40,
#   'current_price': 0.33250001072883606,
#   'DDM': 0},
#  {'ticker': 'IMS.MI',
#   'forcast_price': 1.0532779241826309,
#   'current_price': 0.3869999945163727,
#   'DDM': 0},
#  {'ticker': 'ALREW.PA',
#   'forcast_price': 23.863960549357245,
#   'current_price': 6.579999923706055,
#   'DDM': 0},
#  {'ticker': 'IKG.MI',
#   'forcast_price': 20.170561783275947,
#   'current_price': 0.5210000276565552,
#   'DDM': 0},
#  {'ticker': 'IKGR.MI',
#   'forcast_price': 472.2465053299533,
#   'current_price': 0.765999972820282,
#   'DDM': 0},
#  {'ticker': 'EXM.BR',
#   'forcast_price': 27250929.975664802,
#   'current_price': 4.755000114440918,
#   'DDM': 0},
#  {'ticker': 'SO.MI',
#   'forcast_price': 2.9744085146739194,
#   'current_price': 0.7889999747276306,
#   'DDM': 0},
#  {'ticker': 'ALBIO.PA',
#   'forcast_price': 1205.0438849247105,
#   'current_price': 18.639999389648438,
#   'DDM': 0},
#  {'ticker': 'GUI.PA',
#   'forcast_price': 106.75540518435666,
#   'current_price': 11.119999885559082,
#   'DDM': 0},
#  {'ticker': 'SRP.PA',
#   'forcast_price': 28.004737898697606,
#   'current_price': 1.1799999475479126,
#   'DDM': 0},
#  {'ticker': 'M8G.DE',
#   'forcast_price': 13.863079781714605,
#   'current_price': 2.2279999256134033,
#   'DDM': 0},
#  {'ticker': 'AEF.MI',
#   'forcast_price': 14.667766337564668,
#   'current_price': 1.3819999694824219,
#   'DDM': 0},
#  {'ticker': 'BFE.MI',
#   'forcast_price': 7.658396653774062e+16,
#   'current_price': 0.3070000112056732,
#   'DDM': 0},
#  {'ticker': 'MTV.MI',
#   'forcast_price': 14.980429356748523,
#   'current_price': 0.6589999794960022,
#   'DDM': 0},
#  {'ticker': 'CY4.MI',
#   'forcast_price': 40.94130572098865,
#   'current_price': 8.949999809265137,
#   'DDM': 0},
#  {'ticker': 'BBED.AS',
#   'forcast_price': 61.705656634098084,
#   'current_price': 4.050000190734863,
#   'DDM': 0},
#  {'ticker': 'ACCB.BR',
#   'forcast_price': 0.3909199180489161,
#   'current_price': 0.03700000047683716,
#   'DDM': 0},
#  {'ticker': 'LOCAL.PA',
#   'forcast_price': 21.678997387042582,
#   'current_price': 0.9714999794960022,
#   'DDM': 0},
#  {'ticker': 'ALTUV.PA',
#   'forcast_price': 9.034491122740693,
#   'current_price': 4.519999980926514,
#   'DDM': 0},
#  {'ticker': 'INC.MI',
#   'forcast_price': 3922159973376.963,
#   'current_price': 1.9859999418258667,
#   'DDM': 0},
#  {'ticker': 'MDF.MC',
#   'forcast_price': 1.6953956254941352e+53,
#   'current_price': 0.718999981880188,
#   'DDM': 0},
#  {'ticker': 'XPR.MI',
#   'forcast_price': 2.2461954441067818e+21,
#   'current_price': 1.7200000286102295,
#   'DDM': 0},
#  {'ticker': 'PRL.MI',
#   'forcast_price': 1.1328158259428907,
#   'current_price': 0.18880000710487366,
#   'DDM': 0},
#  {'ticker': 'GAB.MI',
#   'forcast_price': 16.37310370704255,
#   'current_price': 0.9800000190734863,
#   'DDM': 0},
#  {'ticker': 'ALEUP.PA',
#   'forcast_price': 0.1035613690026094,
#   'current_price': 0.0026000000070780516,
#   'DDM': 0},
#  {'ticker': 'TES.MI',
#   'forcast_price': 1.4475465616322718,
#   'current_price': 0.11760000139474869,
#   'DDM': 0},
#  {'ticker': 'INA.LS',
#   'forcast_price': 0.758165290423989,
#   'current_price': 0.023499999195337296,
#   'DDM': 0},
#  {'ticker': 'BO.MI',
#   'forcast_price': 21.694036179203696,
#   'current_price': 0.6620000004768372,
#   'DDM': 0},
#  {'ticker': 'SOU.MI',
#   'forcast_price': 17.3090999028955,
#   'current_price': 4.090000152587891,
#   'DDM': 0},
#  {'ticker': 'ALTBG.PA',
#   'forcast_price': 1.9671723931102245,
#   'current_price': 0.6965000033378601,
#   'DDM': 0},
#  {'ticker': 'ALAGR.PA',
#   'forcast_price': 1.4292053026127376,
#   'current_price': 0.09380000084638596,
#   'DDM': 0},
#  {'ticker': 'BIA.MI',
#   'forcast_price': 5.525655657899916,
#   'current_price': 0.2919999957084656,
#   'DDM': 0},
#  {'ticker': 'M8H.DE',
#   'forcast_price': 0.2571454801294383,
#   'current_price': 0.12950000166893005,
#   'DDM': 0},
#  {'ticker': 'ROOD.AS',
#   'forcast_price': 2.2892452162884562,
#   'current_price': 0.1899999976158142,
#   'DDM': 0},
#  {'ticker': 'AVT.PA',
#   'forcast_price': 1.9987767613018907,
#   'current_price': 0.00989999994635582,
#   'DDM': 0},
#  {'ticker': 'NYE.MC',
#   'forcast_price': 40.16243081747709,
#   'current_price': 0.002199999988079071,
#   'DDM': 0},
#  {'ticker': 'ALLEX.PA',
#   'forcast_price': 643004104389.2996,
#   'current_price': 3.125,
#   'DDM': 0},
#  {'ticker': 'MTF.MI',
#   'forcast_price': 0.33733276280167435,
#   'current_price': 0.020600000396370888,
#   'DDM': 0},
#  {'ticker': 'BIE.MI',
#   'forcast_price': 8.438026275642656,
#   'current_price': 0.07999999821186066,
#   'DDM': 0}]

# %%
undervalued_ddm
# Out:
# [{'ticker': 'UNA.AS',
#   'forcast_price': 8.297566012354231,
#   'current_price': 45.26499938964844,
#   'DDM': 88.92},
#  {'ticker': 'SAN.PA',
#   'forcast_price': 19.504065367278432,
#   'current_price': 97.9000015258789,
#   'DDM': 186.03}]
